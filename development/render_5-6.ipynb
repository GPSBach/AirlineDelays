# %%
import os
import conda

conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

from mpl_toolkits.basemap import Basemap

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pygrib
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
import time

def print_time(t0):
    t1 = time.time()
    return t1-t0

# %%
# starting and ending viewazimuths
azim_start = 270
azim_end = 270

# starting and ending view elevations
elev_start = 90
elev_end = 90

# starting and ending zooms
dist_start = 230
dist_end = 230

# starting and ending center latitude
lat_start = 38.5
lat_end = 38.5

# starting and ending longitude
lon_start = -97.5
lon_end = -97.5

# starting and ending layer separation
delev_start = 0
delev_end = 0

# delta center degrees
# latitude window for center
# tradoff with dist
ddeg = 1

#save files setup
savepath = '../plots/map/movie/animation/'
filename = 'stage5_'


num_steps = 300

t0 = time.time()

variables = ['Total Cloud Cover']
colors = ['viridis']
ranges = [(0,100)]

for i in range(num_steps):
    delev = delev_start-i*((delev_start-delev_end)/(num_steps-1))
    hour = str(i-24*(i//24)).zfill(2)
    day = str(1+i//24).zfill(2)
    try:
        grbs = pygrib.open(f'../data/weather/august_full/rap_130_201808{day}_{hour}00_000.grb2')
    except:
        pass
    
    datas = []
    elev = np.arange(len(variables))*delev

    for variable in variables:
        grb = grbs.select(name=variable)[0]
        lats, lons = grb.latlons()
        datas.append(grb['values'])

    map = Basemap(llcrnrlon=-360,llcrnrlat=-90,urcrnrlon=360,urcrnrlat=90,)

    fig = plt.figure(figsize=[10,10],dpi=150)
    ax = Axes3D(fig)

    ax.add_collection3d(map.drawcoastlines(linewidth=0.25))
    ax.add_collection3d(map.drawcountries(linewidth=0.35))

    ax.set_axis_off()
    ax.azim = azim_start-i*((azim_start-azim_end)/(num_steps-1))
    ax.elev = elev_start-i*((elev_start-elev_end)/(num_steps-1))
    ax.dist = dist_start-i*((dist_start-dist_end)/(num_steps-1))
    
    center_lat = lat_start-i*((lat_start-lat_end)/(num_steps-1))
    center_lon = lon_start-i*((lon_start-lon_end)/(num_steps-1))


    for ix,data in enumerate(datas):
        # fourth dimention - colormap
        # create colormap according to x-value (can use any 50x50 array)
        color_dimension = data # change to desired fourth dimension
        minn, maxx = color_dimension.min(), color_dimension.max()
        norm = matplotlib.colors.Normalize(minn, maxx)
        m = plt.cm.ScalarMappable(norm=norm, cmap=colors[ix])
        m.set_array([])
        fcolors = m.to_rgba(color_dimension)

        ax.plot_surface(lons,lats,np.ones(lats.shape)*elev[ix]+delev/10,cstride=2,rstride=2,facecolors=fcolors, vmin=ranges[ix][0], vmax=ranges[ix][0], shade=False)

    ax.set_xlim3d(center_lon-ddeg,center_lon+ddeg)
    ax.set_ylim3d(center_lat-ddeg,center_lat+ddeg)
    if i < 10:
        fig.savefig(f'{savepath}{filename}0000{i}.png', dpi=fig.dpi)
    elif i >=10 and i < 100:
        fig.savefig(f'{savepath}{filename}000{i}.png', dpi=fig.dpi)
    elif i >=100 and i < 1000:
        fig.savefig(f'{savepath}{filename}00{i}.png', dpi=fig.dpi)
    elif i > 1000:
        fig.savefig(f'{savepath}{filename}0{i}.png', dpi=fig.dpi)
    plt.close()
    print(f'Printed {filename}0000{i}.png in',print_time(t0),'seconds')
    t0 = time.time()
# Out:
# Printed stage5_00000.png in 14.703276872634888 seconds
# Printed stage5_00001.png in 18.315837144851685 seconds
# Printed stage5_00002.png in 16.574342727661133 seconds
# Printed stage5_00003.png in 19.320158004760742 seconds
# Printed stage5_00004.png in 17.785667181015015 seconds
# Printed stage5_00005.png in 17.544862985610962 seconds
# Printed stage5_00006.png in 30.1408371925354 seconds
# Printed stage5_00007.png in 30.048282861709595 seconds
# Printed stage5_00008.png in 27.761106967926025 seconds
# Printed stage5_00009.png in 27.396714210510254 seconds
# Printed stage5_000010.png in 22.519819974899292 seconds
# Printed stage5_000011.png in 20.37186574935913 seconds
# Printed stage5_000012.png in 26.57388734817505 seconds
# Printed stage5_000013.png in 31.827590942382812 seconds
# Printed stage5_000014.png in 19.682866096496582 seconds
# Printed stage5_000015.png in 29.739554166793823 seconds
# Printed stage5_000016.png in 35.858433961868286 seconds
# Printed stage5_000017.png in 33.28414011001587 seconds
# Printed stage5_000018.png in 129.16504096984863 seconds
# Printed stage5_000019.png in 32.775938987731934 seconds
# Printed stage5_000020.png in 39.51283621788025 seconds
# Printed stage5_000021.png in 46.73773407936096 seconds
# Printed stage5_000022.png in 32.48598098754883 seconds
# Printed stage5_000023.png in 45.779603004455566 seconds
# Printed stage5_000024.png in 42.571309089660645 seconds
# Printed stage5_000025.png in 33.608099699020386 seconds
# Printed stage5_000026.png in 36.760188817977905 seconds
# Printed stage5_000027.png in 39.13251709938049 seconds
# Printed stage5_000028.png in 35.341103076934814 seconds
# Printed stage5_000029.png in 68.35724997520447 seconds
# Printed stage5_000030.png in 26.49292302131653 seconds
# Printed stage5_000031.png in 93.83342504501343 seconds
# Printed stage5_000032.png in 44.66915798187256 seconds
# Printed stage5_000033.png in 23.539007425308228 seconds
# Printed stage5_000034.png in 23.36535620689392 seconds
# Printed stage5_000035.png in 154.94071412086487 seconds
# Printed stage5_000036.png in 66.32713413238525 seconds
# Printed stage5_000037.png in 34.24848508834839 seconds
# Printed stage5_000038.png in 56.94214200973511 seconds
# Printed stage5_000039.png in 41.19055795669556 seconds
# Printed stage5_000040.png in 53.51582884788513 seconds
# Printed stage5_000041.png in 52.42250871658325 seconds
# Printed stage5_000042.png in 59.03832006454468 seconds
# Printed stage5_000043.png in 35.30095624923706 seconds
# Printed stage5_000044.png in 57.89692211151123 seconds
# Printed stage5_000045.png in 48.92374610900879 seconds
# Printed stage5_000046.png in 50.9057731628418 seconds
# Printed stage5_000047.png in 46.47788906097412 seconds
# Printed stage5_000048.png in 42.30811405181885 seconds
# Printed stage5_000049.png in 48.74748682975769 seconds
# Printed stage5_000050.png in 39.15907597541809 seconds
# Printed stage5_000051.png in 48.68588995933533 seconds
# Printed stage5_000052.png in 41.82582879066467 seconds
# Printed stage5_000053.png in 48.368680000305176 seconds
# Printed stage5_000054.png in 48.87951707839966 seconds
# Printed stage5_000055.png in 54.20095777511597 seconds
# Printed stage5_000056.png in 56.319194078445435 seconds
# Printed stage5_000057.png in 47.10379600524902 seconds
# Printed stage5_000058.png in 32.72291302680969 seconds
# Printed stage5_000059.png in 59.24511194229126 seconds
# Printed stage5_000060.png in 65.07746481895447 seconds
# Printed stage5_000061.png in 98.54214024543762 seconds
# Printed stage5_000062.png in 67.41380977630615 seconds
# Printed stage5_000063.png in 52.723551988601685 seconds
# Printed stage5_000064.png in 32.53416395187378 seconds
# Printed stage5_000065.png in 43.16018581390381 seconds
# Printed stage5_000066.png in 26.15110182762146 seconds
# Printed stage5_000067.png in 34.473567962646484 seconds
# Printed stage5_000068.png in 38.33268904685974 seconds
# Printed stage5_000069.png in 31.95667290687561 seconds
# Printed stage5_000070.png in 43.566487073898315 seconds
# Printed stage5_000071.png in 32.961912870407104 seconds
# Printed stage5_000072.png in 62.87830400466919 seconds
# Printed stage5_000073.png in 44.6520209312439 seconds
# Printed stage5_000074.png in 26.22320008277893 seconds
# Printed stage5_000075.png in 53.15288209915161 seconds
# Printed stage5_000076.png in 36.85407114028931 seconds
# Printed stage5_000077.png in 64.04522585868835 seconds
# Printed stage5_000078.png in 41.566617250442505 seconds
# Printed stage5_000079.png in 53.151374101638794 seconds
# Printed stage5_000080.png in 47.536280155181885 seconds
# Printed stage5_000081.png in 56.10493278503418 seconds
# Printed stage5_000082.png in 87.25053596496582 seconds
# Printed stage5_000083.png in 51.68877577781677 seconds
# Printed stage5_000084.png in 51.85877704620361 seconds
# Printed stage5_000085.png in 68.03713893890381 seconds
# Printed stage5_000086.png in 29.331680059432983 seconds
# Printed stage5_000087.png in 50.780086040496826 seconds
# Printed stage5_000088.png in 36.63659429550171 seconds
# Printed stage5_000089.png in 23.239253044128418 seconds
# Printed stage5_000090.png in 50.98723483085632 seconds
# Printed stage5_000091.png in 40.87334489822388 seconds
# Printed stage5_000092.png in 43.33019685745239 seconds
# Printed stage5_000093.png in 32.42508387565613 seconds
# Printed stage5_000094.png in 67.44331479072571 seconds
# Printed stage5_000095.png in 30.981823205947876 seconds
# Printed stage5_000096.png in 58.85785222053528 seconds
# Printed stage5_000097.png in 36.09195280075073 seconds
# Printed stage5_000098.png in 48.91103410720825 seconds
# Printed stage5_000099.png in 37.13008403778076 seconds
# Printed stage5_0000100.png in 22.8159339427948 seconds
# Printed stage5_0000101.png in 56.82390475273132 seconds
# Printed stage5_0000102.png in 39.45084309577942 seconds
# Printed stage5_0000103.png in 40.71672511100769 seconds
# Printed stage5_0000104.png in 63.85651612281799 seconds
# Printed stage5_0000105.png in 46.948813915252686 seconds
# Printed stage5_0000106.png in 57.23482704162598 seconds
# Printed stage5_0000107.png in 34.70872974395752 seconds
# Printed stage5_0000108.png in 46.562615156173706 seconds
# Printed stage5_0000109.png in 33.5951030254364 seconds
# Printed stage5_0000110.png in 34.86225414276123 seconds
# Printed stage5_0000111.png in 34.258811712265015 seconds
# Printed stage5_0000112.png in 57.954254150390625 seconds
# Printed stage5_0000113.png in 36.373055934906006 seconds
# Printed stage5_0000114.png in 63.22347283363342 seconds
# Printed stage5_0000115.png in 59.61714291572571 seconds
# Printed stage5_0000116.png in 41.20054292678833 seconds
# Printed stage5_0000117.png in 55.72740411758423 seconds
# Printed stage5_0000118.png in 52.47484803199768 seconds
# Printed stage5_0000119.png in 60.75461196899414 seconds
# Printed stage5_0000120.png in 33.77433180809021 seconds
# Printed stage5_0000121.png in 40.3969841003418 seconds
# Printed stage5_0000122.png in 38.32776093482971 seconds
# Printed stage5_0000123.png in 88.9354658126831 seconds
# Printed stage5_0000124.png in 44.91730999946594 seconds
# Printed stage5_0000125.png in 45.259209871292114 seconds
# Printed stage5_0000126.png in 55.15898609161377 seconds
# Printed stage5_0000127.png in 49.02338409423828 seconds
# Printed stage5_0000128.png in 58.60315012931824 seconds
# Printed stage5_0000129.png in 36.689868211746216 seconds
# Printed stage5_0000130.png in 40.87102389335632 seconds
# Printed stage5_0000131.png in 49.863378286361694 seconds
# Printed stage5_0000132.png in 80.58460903167725 seconds
# Printed stage5_0000133.png in 40.64775109291077 seconds
# Printed stage5_0000134.png in 64.28280806541443 seconds
# Printed stage5_0000135.png in 34.212904930114746 seconds
# Printed stage5_0000136.png in 38.61456274986267 seconds
# Printed stage5_0000137.png in 68.1397271156311 seconds
# Printed stage5_0000138.png in 60.585145235061646 seconds
# Printed stage5_0000139.png in 54.12551808357239 seconds
# Printed stage5_0000140.png in 29.5693781375885 seconds
# Printed stage5_0000141.png in 66.48184823989868 seconds
# Printed stage5_0000142.png in 45.55199217796326 seconds
# Printed stage5_0000143.png in 47.00701975822449 seconds
# Printed stage5_0000144.png in 32.582273960113525 seconds
# Printed stage5_0000145.png in 52.88626003265381 seconds
# Printed stage5_0000146.png in 39.2525110244751 seconds
# Printed stage5_0000147.png in 39.89418983459473 seconds
# Printed stage5_0000148.png in 29.308345079421997 seconds
# Printed stage5_0000149.png in 54.36961603164673 seconds
# Printed stage5_0000150.png in 61.24338698387146 seconds
# Printed stage5_0000151.png in 110.09966278076172 seconds
# Printed stage5_0000152.png in 44.893550872802734 seconds
# Printed stage5_0000153.png in 38.99800395965576 seconds
# Printed stage5_0000154.png in 133.53254389762878 seconds
# Printed stage5_0000155.png in 37.69989800453186 seconds
# Printed stage5_0000156.png in 61.77159404754639 seconds
# Printed stage5_0000157.png in 120.5023672580719 seconds
# Printed stage5_0000158.png in 129.19740319252014 seconds
# Printed stage5_0000159.png in 55.613839864730835 seconds
# Printed stage5_0000160.png in 91.2660391330719 seconds
# Printed stage5_0000161.png in 22.770546913146973 seconds
# Printed stage5_0000162.png in 39.855491161346436 seconds
# Printed stage5_0000163.png in 42.993200063705444 seconds
# Printed stage5_0000164.png in 57.92073702812195 seconds
# Printed stage5_0000165.png in 52.947771072387695 seconds
# Printed stage5_0000166.png in 39.66920280456543 seconds
# Printed stage5_0000167.png in 42.63612174987793 seconds
# Printed stage5_0000168.png in 62.883832931518555 seconds
# Printed stage5_0000169.png in 65.42327094078064 seconds
# Printed stage5_0000170.png in 36.6990749835968 seconds
# Printed stage5_0000171.png in 66.30194306373596 seconds
# Printed stage5_0000172.png in 49.8031439781189 seconds
# Printed stage5_0000173.png in 60.346211194992065 seconds
# Printed stage5_0000174.png in 38.97612500190735 seconds
# Printed stage5_0000175.png in 39.08653402328491 seconds
# Printed stage5_0000176.png in 54.89552092552185 seconds
# Printed stage5_0000177.png in 49.82884621620178 seconds
# Printed stage5_0000178.png in 33.02006816864014 seconds
# Printed stage5_0000179.png in 24.172555923461914 seconds
# Printed stage5_0000180.png in 37.21643400192261 seconds
# Printed stage5_0000181.png in 41.49294590950012 seconds
# Printed stage5_0000182.png in 60.56260824203491 seconds
# Printed stage5_0000183.png in 64.05610418319702 seconds
# Printed stage5_0000184.png in 89.42212009429932 seconds
# Printed stage5_0000185.png in 50.6678831577301 seconds
# Printed stage5_0000186.png in 51.01209211349487 seconds
# Printed stage5_0000187.png in 54.5482611656189 seconds
# Printed stage5_0000188.png in 29.53676986694336 seconds
# Printed stage5_0000189.png in 50.44798183441162 seconds
# Printed stage5_0000190.png in 51.689029693603516 seconds
# Printed stage5_0000191.png in 71.85899996757507 seconds
# Printed stage5_0000192.png in 39.33818006515503 seconds
# Printed stage5_0000193.png in 53.33717918395996 seconds
# Printed stage5_0000194.png in 38.70454001426697 seconds
# Printed stage5_0000195.png in 45.83781576156616 seconds
# Printed stage5_0000196.png in 48.6822350025177 seconds
# Printed stage5_0000197.png in 74.00678706169128 seconds
# Printed stage5_0000198.png in 48.37792205810547 seconds
# Printed stage5_0000199.png in 43.25618386268616 seconds
# Printed stage5_0000200.png in 48.84817719459534 seconds
# Printed stage5_0000201.png in 32.028971910476685 seconds
# Printed stage5_0000202.png in 71.06997990608215 seconds
# Printed stage5_0000203.png in 48.60589385032654 seconds
# Printed stage5_0000204.png in 88.08652997016907 seconds
# Printed stage5_0000205.png in 62.98979210853577 seconds
# Printed stage5_0000206.png in 29.96489715576172 seconds
# Printed stage5_0000207.png in 154.65618991851807 seconds
# Printed stage5_0000208.png in 67.12615084648132 seconds
# Printed stage5_0000209.png in 56.60337710380554 seconds
# Printed stage5_0000210.png in 46.98973202705383 seconds
# Printed stage5_0000211.png in 36.48705315589905 seconds
# Printed stage5_0000212.png in 84.46561694145203 seconds
# Printed stage5_0000213.png in 43.10860228538513 seconds
# Printed stage5_0000214.png in 93.37916421890259 seconds
# Printed stage5_0000215.png in 40.18500781059265 seconds
# Printed stage5_0000216.png in 42.02559494972229 seconds
# Printed stage5_0000217.png in 152.5044229030609 seconds
# Printed stage5_0000218.png in 63.307058811187744 seconds
# Printed stage5_0000219.png in 95.90946364402771 seconds
# Printed stage5_0000220.png in 69.95186281204224 seconds
# Printed stage5_0000221.png in 71.70865893363953 seconds
# Printed stage5_0000222.png in 55.276641845703125 seconds
# Printed stage5_0000223.png in 104.9538779258728 seconds
# Printed stage5_0000224.png in 69.75395202636719 seconds
# Printed stage5_0000225.png in 47.81842279434204 seconds
# Printed stage5_0000226.png in 84.83065605163574 seconds
# Printed stage5_0000227.png in 44.78843426704407 seconds
# Printed stage5_0000228.png in 64.70309090614319 seconds
# Printed stage5_0000229.png in 50.373838901519775 seconds
# Printed stage5_0000230.png in 46.984776973724365 seconds
# Printed stage5_0000231.png in 39.844337940216064 seconds
# Printed stage5_0000232.png in 60.03832817077637 seconds
# Printed stage5_0000233.png in 39.070624113082886 seconds
# Printed stage5_0000234.png in 58.453460931777954 seconds
# Printed stage5_0000235.png in 135.94463801383972 seconds
# Printed stage5_0000236.png in 56.47453212738037 seconds
# Printed stage5_0000237.png in 38.283129930496216 seconds
# Printed stage5_0000238.png in 50.477396965026855 seconds
# Printed stage5_0000239.png in 28.59408712387085 seconds
# Printed stage5_0000240.png in 77.57000494003296 seconds
# Printed stage5_0000241.png in 45.28004813194275 seconds
# Printed stage5_0000242.png in 40.408849239349365 seconds
# Printed stage5_0000243.png in 39.27524781227112 seconds
# Printed stage5_0000244.png in 44.99803805351257 seconds
# Printed stage5_0000245.png in 26.059963703155518 seconds
# Printed stage5_0000246.png in 142.6856210231781 seconds
# Printed stage5_0000247.png in 54.26387619972229 seconds
# Printed stage5_0000248.png in 39.86955380439758 seconds
# Printed stage5_0000249.png in 51.01932215690613 seconds
# Printed stage5_0000250.png in 49.99206590652466 seconds
# Printed stage5_0000251.png in 49.520689964294434 seconds
# Printed stage5_0000252.png in 74.76768493652344 seconds
# Printed stage5_0000253.png in 86.7118079662323 seconds
# Printed stage5_0000254.png in 53.25508999824524 seconds
# Printed stage5_0000255.png in 32.95180296897888 seconds
# Printed stage5_0000256.png in 64.96025085449219 seconds
# Printed stage5_0000257.png in 54.07294011116028 seconds
# Printed stage5_0000258.png in 61.74226498603821 seconds
# Printed stage5_0000259.png in 80.9882550239563 seconds
# Printed stage5_0000260.png in 59.55136203765869 seconds
# Printed stage5_0000261.png in 51.71736717224121 seconds
# Printed stage5_0000262.png in 57.94664192199707 seconds
# Printed stage5_0000263.png in 49.5683159828186 seconds
# Printed stage5_0000264.png in 49.74337196350098 seconds
# Printed stage5_0000265.png in 41.55288505554199 seconds
# Printed stage5_0000266.png in 88.13206791877747 seconds
# Printed stage5_0000267.png in 60.26173710823059 seconds
# Printed stage5_0000268.png in 44.442058086395264 seconds
# Printed stage5_0000269.png in 84.83481311798096 seconds
# Printed stage5_0000270.png in 88.48872089385986 seconds
# Printed stage5_0000271.png in 61.64685297012329 seconds
# Printed stage5_0000272.png in 97.79021692276001 seconds
# Printed stage5_0000273.png in 75.70778918266296 seconds
# Printed stage5_0000274.png in 88.2404248714447 seconds
# Printed stage5_0000275.png in 76.4836699962616 seconds
# Printed stage5_0000276.png in 46.028932094573975 seconds
# Printed stage5_0000277.png in 45.47169208526611 seconds
# Printed stage5_0000278.png in 23.06411385536194 seconds
# Printed stage5_0000279.png in 115.26085495948792 seconds
# Printed stage5_0000280.png in 49.53263998031616 seconds
# Printed stage5_0000281.png in 28.22351312637329 seconds
# Printed stage5_0000282.png in 26.20707082748413 seconds
# Printed stage5_0000283.png in 44.373701095581055 seconds
# Printed stage5_0000284.png in 27.730234146118164 seconds
# Printed stage5_0000285.png in 56.178229093551636 seconds
# Printed stage5_0000286.png in 86.56264114379883 seconds
# Printed stage5_0000287.png in 57.98217821121216 seconds
# Printed stage5_0000288.png in 41.60344195365906 seconds
# Printed stage5_0000289.png in 50.99613118171692 seconds
# Printed stage5_0000290.png in 35.918309688568115 seconds
# Printed stage5_0000291.png in 47.630187034606934 seconds
# Printed stage5_0000292.png in 37.017557859420776 seconds
# Printed stage5_0000293.png in 68.44460487365723 seconds
# Printed stage5_0000294.png in 85.55394673347473 seconds
# Printed stage5_0000295.png in 51.089725971221924 seconds
# Printed stage5_0000296.png in 63.76600480079651 seconds
# Printed stage5_0000297.png in 42.48701500892639 seconds
# Printed stage5_0000298.png in 115.87017297744751 seconds
# Printed stage5_0000299.png in 78.07521414756775 seconds

# %%
# starting and ending viewazimuths
azim_start = 270
azim_end = 270

# starting and ending view elevations
elev_start = 90
elev_end = 90

# starting and ending zooms
dist_start = 230
dist_end = 230#100

#airport coordinates
lat_DEN = 39.7392
lon_DEN = -104.9903
lat_MIA = 25.7617
lon_MIA = -80.1918

# starting and ending center latitude
lat_start = 38.5
lat_end = 38.5#(lat_DEN+lat_MIA)/2

# starting and ending longitude
lon_start = -97.5
lon_end = -97.5#(lon_DEN+lon_MIA)/2

# starting and ending layer separation
delev_start = 0
delev_end = 0

#latitude windows
degree_window_start = 38
degree_window_end = 5


# delta center degrees
# latitude window for center
# tradoff with dist
ddeg = 1

#save files setup
savepath = '../plots/map/movie/animation/'
filename = 'stage6_'


num_steps = 300

t0 = time.time()

variables = ['Total Cloud Cover']
colors = ['viridis']
ranges = [(0,100)]

for i in range(num_steps):
    delev = delev_start-i*((delev_start-delev_end)/(num_steps-1))
    degree_window = degree_window_start-i*((degree_window_start-degree_window_end)/(num_steps-1))
    hour = str(i-24*(i//24)).zfill(2)
    day = str(1+i//24).zfill(2)
    try:
        grbs = pygrib.open(f'../data/weather/august_full/rap_130_201808{day}_{hour}00_000.grb2')
    except:
        pass
    
    datas = []
    elev = np.arange(len(variables))*delev

    for variable in variables:
        grb = grbs.select(name=variable)[0]
        lats, lons = grb.latlons()
        datas.append(grb['values'])

    map = Basemap(llcrnrlon=-360,llcrnrlat=-90,urcrnrlon=360,urcrnrlat=90,)

    fig = plt.figure(figsize=[10,10],dpi=150)
    ax = Axes3D(fig)

    ax.add_collection3d(map.drawcoastlines(linewidth=0.25))
    ax.add_collection3d(map.drawcountries(linewidth=0.35))

    ax.set_axis_off()
    ax.azim = azim_start-i*((azim_start-azim_end)/(num_steps-1))
    ax.elev = elev_start-i*((elev_start-elev_end)/(num_steps-1))
    ax.dist = dist_start-i*((dist_start-dist_end)/(num_steps-1))
    
    center_lat = lat_start-i*((lat_start-lat_end)/(num_steps-1))
    center_lon = lon_start-i*((lon_start-lon_end)/(num_steps-1))


    for ix,data in enumerate(datas):
        # fourth dimention - colormap
        # create colormap according to x-value (can use any 50x50 array)
        color_dimension = data # change to desired fourth dimension
        minn, maxx = color_dimension.min(), color_dimension.max()
        norm = matplotlib.colors.Normalize(minn, maxx)
        m = plt.cm.ScalarMappable(norm=norm, cmap=colors[ix])
        m.set_array([])
        fcolors = m.to_rgba(color_dimension)
        Z_DEN = np.ones(lats.shape)*elev[ix]+delev/10
        Z_MIA = np.ones(lats.shape)*elev[ix]+delev/10
        mask_DEN = np.ma.masked_where((np.sqrt((lats-lat_DEN)**2 + (lons-lon_DEN)**2) > degree_window), Z_DEN)
        mask_MIA = np.ma.masked_where((np.sqrt((lats-lat_MIA)**2 + (lons-lon_MIA)**2) > degree_window), Z_MIA)
        Z_DEN[np.where(np.ma.getmask(mask_DEN)==True)] = np.nan # or np.where(np.ma.getmask(mask2)==True)] = np.nan
        Z_MIA[np.where(np.ma.getmask(mask_MIA)==True)] = np.nan
        
        ax.plot_surface(lons,lats,Z_DEN,cstride=2,rstride=2,facecolors=fcolors, vmin=ranges[ix][0], vmax=ranges[ix][0], shade=False)
        ax.plot_surface(lons,lats,Z_MIA,cstride=2,rstride=2,facecolors=fcolors, vmin=ranges[ix][0], vmax=ranges[ix][0], shade=False)

    ax.set_xlim3d(center_lon-ddeg,center_lon+ddeg)
    ax.set_ylim3d(center_lat-ddeg,center_lat+ddeg)
    if i < 10:
        fig.savefig(f'{savepath}{filename}0000{i}.png', dpi=fig.dpi)
    elif i >=10 and i < 100:
        fig.savefig(f'{savepath}{filename}000{i}.png', dpi=fig.dpi)
    elif i >=100 and i < 1000:
        fig.savefig(f'{savepath}{filename}00{i}.png', dpi=fig.dpi)
    elif i > 1000:
        fig.savefig(f'{savepath}{filename}0{i}.png', dpi=fig.dpi)
    plt.close()
    print(f'Printed {filename}0000{i}.png in',print_time(t0),'seconds')
    t0 = time.time()
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# Printed stage6_00000.png in 182.83209085464478 seconds
# Printed stage6_00001.png in 36.40432620048523 seconds
# Printed stage6_00002.png in 35.77442526817322 seconds
# Printed stage6_00003.png in 53.016205072402954 seconds
# Printed stage6_00004.png in 75.49617981910706 seconds
# Printed stage6_00005.png in 50.17802715301514 seconds
# Printed stage6_00006.png in 65.02593278884888 seconds
# Printed stage6_00007.png in 50.444790840148926 seconds
# Printed stage6_00008.png in 78.10461592674255 seconds
# Printed stage6_00009.png in 88.68621730804443 seconds
# Printed stage6_000010.png in 69.42919516563416 seconds
# Printed stage6_000011.png in 124.20846104621887 seconds
# Printed stage6_000012.png in 104.0848970413208 seconds
# Printed stage6_000013.png in 116.78483605384827 seconds
# Printed stage6_000014.png in 168.62775015830994 seconds
# Printed stage6_000015.png in 162.70654010772705 seconds
# Printed stage6_000016.png in 158.01411604881287 seconds
# Printed stage6_000017.png in 164.8190050125122 seconds
# Printed stage6_000018.png in 73.28028988838196 seconds
# Printed stage6_000019.png in 128.94861888885498 seconds
# Printed stage6_000020.png in 75.0172119140625 seconds
# Printed stage6_000021.png in 98.84397006034851 seconds
# Printed stage6_000022.png in 56.88973903656006 seconds
# Printed stage6_000023.png in 80.92205309867859 seconds
# Printed stage6_000024.png in 128.6729371547699 seconds
# Printed stage6_000025.png in 101.9813780784607 seconds
# Printed stage6_000026.png in 89.0343177318573 seconds
# Printed stage6_000027.png in 82.84825301170349 seconds
# Printed stage6_000028.png in 91.02921485900879 seconds
# Printed stage6_000029.png in 94.35502409934998 seconds
# Printed stage6_000030.png in 86.64252591133118 seconds
# Printed stage6_000031.png in 78.45487380027771 seconds
# Printed stage6_000032.png in 71.46979188919067 seconds
# Printed stage6_000033.png in 85.09086394309998 seconds
# Printed stage6_000034.png in 72.2822618484497 seconds
# Printed stage6_000035.png in 132.22364330291748 seconds
# Printed stage6_000036.png in 108.05660605430603 seconds
# Printed stage6_000037.png in 94.29699301719666 seconds
# Printed stage6_000038.png in 104.54822993278503 seconds
# Printed stage6_000039.png in 134.6765649318695 seconds
# Printed stage6_000040.png in 137.55901169776917 seconds
# Printed stage6_000041.png in 57.476353883743286 seconds
# Printed stage6_000042.png in 57.16914391517639 seconds
# Printed stage6_000043.png in 83.14533615112305 seconds
# Printed stage6_000044.png in 100.88841199874878 seconds
# Printed stage6_000045.png in 109.26186609268188 seconds
# Printed stage6_000046.png in 68.02177381515503 seconds
# Printed stage6_000047.png in 155.4743790626526 seconds
# Printed stage6_000048.png in 107.15684819221497 seconds
# Printed stage6_000049.png in 85.72662997245789 seconds
# Printed stage6_000050.png in 94.38075733184814 seconds
# Printed stage6_000051.png in 157.16417503356934 seconds
# Printed stage6_000052.png in 96.59283113479614 seconds
# Printed stage6_000053.png in 173.09546899795532 seconds
# Printed stage6_000054.png in 98.37307786941528 seconds
# Printed stage6_000055.png in 61.419267654418945 seconds
# Printed stage6_000056.png in 75.76767587661743 seconds
# Printed stage6_000057.png in 85.10952401161194 seconds
# Printed stage6_000058.png in 53.565048933029175 seconds
# Printed stage6_000059.png in 61.097529888153076 seconds
# Printed stage6_000060.png in 80.8471429347992 seconds
# Printed stage6_000061.png in 57.11977219581604 seconds
# Printed stage6_000062.png in 66.63843393325806 seconds
# Printed stage6_000063.png in 63.73024892807007 seconds
# Printed stage6_000064.png in 116.89314794540405 seconds
# Printed stage6_000065.png in 46.50666403770447 seconds
# Printed stage6_000066.png in 95.29872798919678 seconds
# Printed stage6_000067.png in 117.69859790802002 seconds
# Printed stage6_000068.png in 113.61206912994385 seconds
# Printed stage6_000069.png in 182.06461715698242 seconds
# Printed stage6_000070.png in 114.36394596099854 seconds
# Printed stage6_000071.png in 114.7638099193573 seconds
# Printed stage6_000072.png in 113.32301306724548 seconds
# Printed stage6_000073.png in 64.44549131393433 seconds
# Printed stage6_000074.png in 68.756511926651 seconds
# Printed stage6_000075.png in 134.53761887550354 seconds
# Printed stage6_000076.png in 155.80311608314514 seconds
# Printed stage6_000077.png in 119.87184619903564 seconds
# Printed stage6_000078.png in 118.37706971168518 seconds
# Printed stage6_000079.png in 96.81106615066528 seconds
# Printed stage6_000080.png in 112.6811249256134 seconds
# Printed stage6_000081.png in 147.42166209220886 seconds
# Printed stage6_000082.png in 79.3235170841217 seconds
# Printed stage6_000083.png in 72.53055572509766 seconds
# Printed stage6_000084.png in 103.15415620803833 seconds
# Printed stage6_000085.png in 62.19358205795288 seconds
# Printed stage6_000086.png in 190.0179958343506 seconds
# Printed stage6_000087.png in 150.5228340625763 seconds
# Printed stage6_000088.png in 105.76033520698547 seconds
# Printed stage6_000089.png in 75.22970700263977 seconds
# Printed stage6_000090.png in 122.48766994476318 seconds
# Printed stage6_000091.png in 80.91065907478333 seconds
# Printed stage6_000092.png in 144.444317817688 seconds
# Printed stage6_000093.png in 146.21512007713318 seconds
# Printed stage6_000094.png in 114.24821019172668 seconds
# Printed stage6_000095.png in 91.94483304023743 seconds
# Printed stage6_000096.png in 106.9683940410614 seconds
# Printed stage6_000097.png in 78.33022284507751 seconds
# Printed stage6_000098.png in 68.93904519081116 seconds
# Printed stage6_000099.png in 89.5106430053711 seconds
# Printed stage6_0000100.png in 109.1541759967804 seconds
# Printed stage6_0000101.png in 108.29600596427917 seconds
# Printed stage6_0000102.png in 121.79938101768494 seconds
