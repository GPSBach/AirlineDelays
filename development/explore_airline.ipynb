# %%
import pandas as pd
pd.options.display.max_columns = 999
import missingno as msno
# %matplotlib inline

# %%
flights = pd.read_csv('../data/flights/2018_08.csv')
airports = pd.read_csv('../data/flights/airport_metadata.csv')

# %%
airports.columns
# Out:
# Index(['AIRPORT_ID', 'AIRPORT', 'DISPLAY_AIRPORT_NAME',
#        'DISPLAY_AIRPORT_CITY_NAME_FULL', 'LATITUDE', 'LONGITUDE',
#        'AIRPORT_START_DATE', 'AIRPORT_THRU_DATE', 'Unnamed: 8'],
#       dtype='object')

# %%
flights.columns
# Out:
# Index(['YEAR', 'MONTH', 'FL_DATE', 'OP_UNIQUE_CARRIER', 'TAIL_NUM',
#        'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID', 'CRS_DEP_TIME', 'DEP_TIME',
#        'DEP_DELAY', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY', 'CANCELLED',
#        'CANCELLATION_CODE', 'CRS_ELAPSED_TIME', 'CARRIER_DELAY',
#        'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY',
#        'Unnamed: 21'],
#       dtype='object')

# %%
flights.head()
# Out:
#    YEAR  MONTH     FL_DATE OP_UNIQUE_CARRIER TAIL_NUM  ORIGIN_AIRPORT_ID  \
# 0  2018      8  2018-08-12                AA   N884NN              11996
# 1  2018      8  2018-08-13                AA   N862NN              11996
# 2  2018      8  2018-08-14                AA   N880NN              11996
# 3  2018      8  2018-08-15                AA   N945NN              11996
# 4  2018      8  2018-08-16                AA   N830NN              11996
#
#    DEST_AIRPORT_ID  CRS_DEP_TIME  DEP_TIME  DEP_DELAY  CRS_ARR_TIME  ARR_TIME  \
# 0            11298           805     757.0       -8.0           950     933.0
# 1            11298           805     806.0        1.0           950     939.0
# 2            11298           805     805.0        0.0           950     928.0
# 3            11298           805     800.0       -5.0           950     935.0
# 4            11298           805     801.0       -4.0           950     930.0
#
# ...

# %%
airports.head()
# Out:
#    AIRPORT_ID AIRPORT     DISPLAY_AIRPORT_NAME DISPLAY_AIRPORT_CITY_NAME_FULL  \
# 0       10001     01A     Afognak Lake Airport               Afognak Lake, AK
# 1       10003     03A  Bear Creek Mining Strip           Granite Mountain, AK
# 2       10004     04A          Lik Mining Camp                        Lik, AK
# 3       10005     05A     Little Squaw Airport               Little Squaw, AK
# 4       10006     06A             Kizhuyak Bay                   Kizhuyak, AK
#
#     LATITUDE   LONGITUDE AIRPORT_START_DATE AIRPORT_THRU_DATE  Unnamed: 8
# 0  58.109444 -152.906667         2007-07-01               NaN         NaN
# 1  65.548056 -161.071667         2007-07-01               NaN         NaN
# 2  68.083333 -163.166667         2007-07-01               NaN         NaN
# 3  67.570000 -148.183889         2007-08-01               NaN         NaN
# 4  57.745278 -152.882778         2007-10-01               NaN         NaN

# %%
flights['FL_DATE']=pd.to_datetime(flights['FL_DATE'],infer_datetime_format=True)

# %%
merge1 = flights.merge(airports.drop_duplicates(subset=['AIRPORT_ID']),left_on='ORIGIN_AIRPORT_ID',right_on='AIRPORT_ID',how='left')

# %%
print(flights.shape,airports.drop_duplicates(subset=['AIRPORT_ID']).shape)
# Out:
# (644673, 22) (6492, 9)

# %%
msno.bar(merge1[merge1['CANCELLATION_CODE']=='B'])

# %%
merge1.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-dee6cc736184> in <module>()
# ----> 1 merge1.shape
#
# AttributeError: 'tuple' object has no attribute 'shape'
