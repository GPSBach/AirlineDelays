# %%
import os
import conda

conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

from mpl_toolkits.basemap import Basemap

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pygrib
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
import time

def print_time(t0):
    t1 = time.time()
    return t1-t0

# %%
# starting and ending viewazimuths
azim_start = 200
azim_end = 200

# starting and ending view elevations
elev_start = 30
elev_end = 30

# starting and ending zooms
dist_start = 250
dist_end = 250

# starting and ending center latitude
lat_start = 50
lat_end = 50

# starting and ending longitude
lon_start = -80
lon_end = -80

# starting and ending layer separation
delev_start = 5
delev_end = 5

# delta center degrees
# latitude window for center
# tradoff with dist
ddeg = 1

#save files setup
savepath = '../plots/map/movie/animation/'
filename = 'stage3_'


num_steps = 300

t0 = time.time()

variables = ['Wind speed (gust)','Visibility','Maximum/Composite radar reflectivity','Total Cloud Cover']
colors = ['viridis','magma','jet','viridis']
ranges = [(0,10),(0,90000),(-10,50),(0,100)]

for i in range(num_steps):
    delev = delev_start-i*((delev_start-delev_end)/(num_steps-1))
    hour = str(i-24*(i//24)).zfill(2)
    day = str(1+i//24).zfill(2)
    try:
        grbs = pygrib.open(f'../data/weather/august_full/rap_130_201808{day}_{hour}00_000.grb2')
    except:
        pass
    
    datas = []
    elev = np.arange(len(variables))*delev

    for variable in variables:
        grb = grbs.select(name=variable)[0]
        lats, lons = grb.latlons()
        datas.append(grb['values'])

    map = Basemap(llcrnrlon=-360,llcrnrlat=-90,urcrnrlon=360,urcrnrlat=90,)

    fig = plt.figure(figsize=[10,10],dpi=150)
    ax = Axes3D(fig)

    ax.add_collection3d(map.drawcoastlines(linewidth=0.25))
    ax.add_collection3d(map.drawcountries(linewidth=0.35))

    ax.set_axis_off()
    ax.azim = azim_start-i*((azim_start-azim_end)/(num_steps-1))
    ax.elev = elev_start-i*((elev_start-elev_end)/(num_steps-1))
    ax.dist = dist_start-i*((dist_start-dist_end)/(num_steps-1))
    
    center_lat = lat_start-i*((lat_start-lat_end)/(num_steps-1))
    center_lon = lon_start-i*((lon_start-lon_end)/(num_steps-1))


    for ix,data in enumerate(datas):
        # fourth dimention - colormap
        # create colormap according to x-value (can use any 50x50 array)
        color_dimension = data # change to desired fourth dimension
        minn, maxx = color_dimension.min(), color_dimension.max()
        norm = matplotlib.colors.Normalize(minn, maxx)
        m = plt.cm.ScalarMappable(norm=norm, cmap=colors[ix])
        m.set_array([])
        fcolors = m.to_rgba(color_dimension)

        ax.plot_surface(lons,lats,np.ones(lats.shape)*elev[ix]+delev/10,cstride=5,rstride=5,facecolors=fcolors, vmin=ranges[ix][0], vmax=ranges[ix][0], shade=False)

    ax.set_xlim3d(center_lon-ddeg,center_lon+ddeg)
    ax.set_ylim3d(center_lat-ddeg,center_lat+ddeg)
    if i < 10:
        fig.savefig(f'{savepath}{filename}0000{i}.png', dpi=fig.dpi)
    elif i >=10 and i < 100:
        fig.savefig(f'{savepath}{filename}000{i}.png', dpi=fig.dpi)
    elif i >=100 and i < 1000:
        fig.savefig(f'{savepath}{filename}00{i}.png', dpi=fig.dpi)
    elif i > 1000:
        fig.savefig(f'{savepath}{filename}0{i}.png', dpi=fig.dpi)
    plt.close()
    print(f'Printed {filename}0000{i}.png in',print_time(t0),'seconds')
    t0 = time.time()
# Out:
# Printed stage3_00000.png in 15.293901920318604 seconds
# Printed stage3_00001.png in 15.139692068099976 seconds
# Printed stage3_00002.png in 17.820783138275146 seconds
# Printed stage3_00003.png in 18.21835708618164 seconds
# Printed stage3_00004.png in 17.13685131072998 seconds
# Printed stage3_00005.png in 15.931737184524536 seconds
# Printed stage3_00006.png in 15.299463987350464 seconds
# Printed stage3_00007.png in 15.178648948669434 seconds
# Printed stage3_00008.png in 15.773086071014404 seconds
# Printed stage3_00009.png in 15.20265793800354 seconds
# Printed stage3_000010.png in 15.806948184967041 seconds
# Printed stage3_000011.png in 15.504855871200562 seconds
# Printed stage3_000012.png in 14.744480609893799 seconds
# Printed stage3_000013.png in 14.788241147994995 seconds
# Printed stage3_000014.png in 17.49171209335327 seconds
# Printed stage3_000015.png in 17.65628409385681 seconds
# Printed stage3_000016.png in 17.825826168060303 seconds
# Printed stage3_000017.png in 18.509485006332397 seconds
# Printed stage3_000018.png in 17.792291164398193 seconds
# Printed stage3_000019.png in 17.34592580795288 seconds
# Printed stage3_000020.png in 17.70197582244873 seconds
# Printed stage3_000021.png in 18.036965131759644 seconds
# Printed stage3_000022.png in 16.942604780197144 seconds
# Printed stage3_000023.png in 18.421756982803345 seconds
# Printed stage3_000024.png in 19.02829599380493 seconds
# Printed stage3_000025.png in 17.73433518409729 seconds
# Printed stage3_000026.png in 17.345465183258057 seconds
# Printed stage3_000027.png in 18.524779081344604 seconds
# Printed stage3_000028.png in 17.21673083305359 seconds
# Printed stage3_000029.png in 18.273157835006714 seconds
# Printed stage3_000030.png in 19.61595582962036 seconds
# Printed stage3_000031.png in 30.296464204788208 seconds
# Printed stage3_000032.png in 34.01463723182678 seconds
# Printed stage3_000033.png in 23.417516946792603 seconds
# Printed stage3_000034.png in 25.155436754226685 seconds
# Printed stage3_000035.png in 25.992491960525513 seconds
# Printed stage3_000036.png in 23.175490856170654 seconds
# Printed stage3_000037.png in 24.90215516090393 seconds
# Printed stage3_000038.png in 23.389684915542603 seconds
# Printed stage3_000039.png in 23.036760091781616 seconds
# Printed stage3_000040.png in 23.888521909713745 seconds
# Printed stage3_000041.png in 17.843384265899658 seconds
# Printed stage3_000042.png in 18.416406869888306 seconds
# Printed stage3_000043.png in 18.24892783164978 seconds
# Printed stage3_000044.png in 19.92690896987915 seconds
# Printed stage3_000045.png in 19.996576070785522 seconds
# Printed stage3_000046.png in 20.029105186462402 seconds
# Printed stage3_000047.png in 21.62011694908142 seconds
# Printed stage3_000048.png in 23.245031118392944 seconds
# Printed stage3_000049.png in 26.213417291641235 seconds
# Printed stage3_000050.png in 21.016721963882446 seconds
# Printed stage3_000051.png in 21.956464052200317 seconds
# Printed stage3_000052.png in 21.273449897766113 seconds
# Printed stage3_000053.png in 21.911031007766724 seconds
# Printed stage3_000054.png in 19.352830171585083 seconds
# Printed stage3_000055.png in 17.63972568511963 seconds
# Printed stage3_000056.png in 17.163097143173218 seconds
# Printed stage3_000057.png in 17.4357271194458 seconds
# Printed stage3_000058.png in 19.240785837173462 seconds
# Printed stage3_000059.png in 17.459580898284912 seconds
# Printed stage3_000060.png in 17.366254091262817 seconds
# Printed stage3_000061.png in 16.820747137069702 seconds
# Printed stage3_000062.png in 17.313690185546875 seconds
# Printed stage3_000063.png in 19.54061222076416 seconds
# Printed stage3_000064.png in 21.67641806602478 seconds
# Printed stage3_000065.png in 18.12434697151184 seconds
# Printed stage3_000066.png in 17.587352991104126 seconds
# Printed stage3_000067.png in 18.142245054244995 seconds
# Printed stage3_000068.png in 17.793215036392212 seconds
# Printed stage3_000069.png in 17.959048986434937 seconds
# Printed stage3_000070.png in 18.08319592475891 seconds
# Printed stage3_000071.png in 17.500549793243408 seconds
# Printed stage3_000072.png in 17.834467887878418 seconds
# Printed stage3_000073.png in 19.26678705215454 seconds
# Printed stage3_000074.png in 21.952395915985107 seconds
# Printed stage3_000075.png in 19.572696924209595 seconds
# Printed stage3_000076.png in 18.476299047470093 seconds
# Printed stage3_000077.png in 18.781660318374634 seconds
# Printed stage3_000078.png in 18.793711185455322 seconds
# Printed stage3_000079.png in 20.80561399459839 seconds
# Printed stage3_000080.png in 21.597628116607666 seconds
# Printed stage3_000081.png in 23.220405101776123 seconds
# Printed stage3_000082.png in 19.367337942123413 seconds
# Printed stage3_000083.png in 19.20465397834778 seconds
# Printed stage3_000084.png in 17.806342840194702 seconds
# Printed stage3_000085.png in 20.387895822525024 seconds
# Printed stage3_000086.png in 20.700343132019043 seconds
# Printed stage3_000087.png in 19.53597378730774 seconds
# Printed stage3_000088.png in 19.602537155151367 seconds
# Printed stage3_000089.png in 18.663002967834473 seconds
# Printed stage3_000090.png in 24.135122776031494 seconds
# Printed stage3_000091.png in 21.079386234283447 seconds
# Printed stage3_000092.png in 19.594308137893677 seconds
# Printed stage3_000093.png in 19.80734920501709 seconds
# Printed stage3_000094.png in 21.054555892944336 seconds
# Printed stage3_000095.png in 23.65526795387268 seconds
# Printed stage3_000096.png in 18.25774097442627 seconds
# Printed stage3_000097.png in 17.00570797920227 seconds
# Printed stage3_000098.png in 15.794627904891968 seconds
# Printed stage3_000099.png in 16.81303906440735 seconds
# Printed stage3_0000100.png in 16.663973093032837 seconds
# Printed stage3_0000101.png in 17.820389986038208 seconds
# Printed stage3_0000102.png in 16.152040004730225 seconds
# Printed stage3_0000103.png in 16.71241807937622 seconds
# Printed stage3_0000104.png in 17.709527015686035 seconds
# Printed stage3_0000105.png in 19.59835696220398 seconds
# Printed stage3_0000106.png in 18.186573028564453 seconds
# Printed stage3_0000107.png in 20.20970320701599 seconds
# Printed stage3_0000108.png in 20.053109884262085 seconds
# Printed stage3_0000109.png in 18.60200309753418 seconds
# Printed stage3_0000110.png in 20.365411043167114 seconds
# Printed stage3_0000111.png in 19.90514898300171 seconds
# Printed stage3_0000112.png in 18.962024211883545 seconds
# Printed stage3_0000113.png in 20.410340070724487 seconds
# Printed stage3_0000114.png in 20.977277040481567 seconds
# Printed stage3_0000115.png in 22.807262897491455 seconds
# Printed stage3_0000116.png in 24.008328914642334 seconds
# Printed stage3_0000117.png in 16.330520153045654 seconds
# Printed stage3_0000118.png in 16.560720205307007 seconds
# Printed stage3_0000119.png in 17.18283987045288 seconds
# Printed stage3_0000120.png in 16.497891902923584 seconds
# Printed stage3_0000121.png in 17.02099084854126 seconds
# Printed stage3_0000122.png in 17.59573984146118 seconds
# Printed stage3_0000123.png in 16.374637126922607 seconds
# Printed stage3_0000124.png in 16.85780906677246 seconds
# Printed stage3_0000125.png in 15.832369804382324 seconds
# Printed stage3_0000126.png in 17.197680950164795 seconds
# Printed stage3_0000127.png in 17.24587392807007 seconds
# Printed stage3_0000128.png in 16.383774042129517 seconds
# Printed stage3_0000129.png in 15.004754781723022 seconds
# Printed stage3_0000130.png in 13.967679023742676 seconds
# Printed stage3_0000131.png in 15.131065130233765 seconds
# Printed stage3_0000132.png in 15.206138849258423 seconds
# Printed stage3_0000133.png in 16.154911041259766 seconds
# Printed stage3_0000134.png in 16.008816957473755 seconds
# Printed stage3_0000135.png in 16.02069592475891 seconds
# Printed stage3_0000136.png in 16.13835072517395 seconds
# Printed stage3_0000137.png in 14.44516110420227 seconds
# Printed stage3_0000138.png in 17.703707933425903 seconds
# Printed stage3_0000139.png in 17.30123209953308 seconds
# Printed stage3_0000140.png in 19.804726123809814 seconds
# Printed stage3_0000141.png in 19.32105278968811 seconds
# Printed stage3_0000142.png in 18.284841299057007 seconds
# Printed stage3_0000143.png in 15.905499935150146 seconds
# Printed stage3_0000144.png in 17.16224479675293 seconds
# Printed stage3_0000145.png in 16.145238637924194 seconds
# Printed stage3_0000146.png in 17.24678921699524 seconds
# Printed stage3_0000147.png in 15.913497686386108 seconds
# Printed stage3_0000148.png in 17.004045009613037 seconds
# Printed stage3_0000149.png in 15.861141920089722 seconds
# Printed stage3_0000150.png in 15.729620933532715 seconds
# Printed stage3_0000151.png in 13.531240940093994 seconds
# Printed stage3_0000152.png in 14.598107814788818 seconds
# Printed stage3_0000153.png in 13.698099136352539 seconds
# Printed stage3_0000154.png in 14.546773672103882 seconds
# Printed stage3_0000155.png in 13.581058740615845 seconds
# Printed stage3_0000156.png in 14.956077814102173 seconds
# Printed stage3_0000157.png in 13.735598087310791 seconds
# Printed stage3_0000158.png in 14.743324756622314 seconds
# Printed stage3_0000159.png in 13.461682796478271 seconds
# Printed stage3_0000160.png in 14.731123924255371 seconds
# Printed stage3_0000161.png in 13.785889148712158 seconds
# Printed stage3_0000162.png in 14.938127040863037 seconds
# Printed stage3_0000163.png in 13.496059894561768 seconds
# Printed stage3_0000164.png in 15.266966104507446 seconds
# Printed stage3_0000165.png in 14.521846055984497 seconds
# Printed stage3_0000166.png in 13.90855097770691 seconds
# Printed stage3_0000167.png in 15.550857782363892 seconds
# Printed stage3_0000168.png in 13.763566970825195 seconds
# Printed stage3_0000169.png in 15.126894235610962 seconds
# Printed stage3_0000170.png in 14.135572910308838 seconds
# Printed stage3_0000171.png in 15.216117858886719 seconds
# Printed stage3_0000172.png in 14.837082862854004 seconds
# Printed stage3_0000173.png in 16.22661805152893 seconds
# Printed stage3_0000174.png in 13.729416847229004 seconds
# Printed stage3_0000175.png in 13.608711957931519 seconds
# Printed stage3_0000176.png in 14.850841045379639 seconds
# Printed stage3_0000177.png in 13.626917839050293 seconds
# Printed stage3_0000178.png in 15.566137075424194 seconds
# Printed stage3_0000179.png in 13.605772256851196 seconds
# Printed stage3_0000180.png in 15.134052991867065 seconds
# Printed stage3_0000181.png in 14.02319598197937 seconds
# Printed stage3_0000182.png in 13.901824951171875 seconds
# Printed stage3_0000183.png in 15.735647916793823 seconds
# Printed stage3_0000184.png in 13.6114821434021 seconds
# Printed stage3_0000185.png in 15.676571130752563 seconds
# Printed stage3_0000186.png in 13.921417951583862 seconds
# Printed stage3_0000187.png in 13.626719951629639 seconds
# Printed stage3_0000188.png in 15.782778978347778 seconds
# Printed stage3_0000189.png in 13.695169925689697 seconds
# Printed stage3_0000190.png in 15.835493803024292 seconds
# Printed stage3_0000191.png in 13.605418920516968 seconds
# Printed stage3_0000192.png in 13.65950608253479 seconds
# Printed stage3_0000193.png in 16.25796890258789 seconds
# Printed stage3_0000194.png in 14.355481147766113 seconds
# Printed stage3_0000195.png in 15.1819908618927 seconds
# Printed stage3_0000196.png in 15.089344024658203 seconds
# Printed stage3_0000197.png in 14.16361117362976 seconds
# Printed stage3_0000198.png in 17.52936816215515 seconds
# Printed stage3_0000199.png in 15.986236810684204 seconds
# Printed stage3_0000200.png in 17.464221954345703 seconds
# Printed stage3_0000201.png in 18.797404766082764 seconds
# Printed stage3_0000202.png in 15.97459888458252 seconds
# Printed stage3_0000203.png in 18.1629159450531 seconds
# Printed stage3_0000204.png in 15.927561044692993 seconds
# Printed stage3_0000205.png in 16.087496995925903 seconds
# Printed stage3_0000206.png in 18.341705799102783 seconds
# Printed stage3_0000207.png in 16.34768009185791 seconds
# Printed stage3_0000208.png in 15.7949378490448 seconds
# Printed stage3_0000209.png in 15.547922134399414 seconds
# Printed stage3_0000210.png in 13.781371116638184 seconds
# Printed stage3_0000211.png in 15.2396240234375 seconds
# Printed stage3_0000212.png in 14.056965112686157 seconds
# Printed stage3_0000213.png in 13.848012924194336 seconds
# Printed stage3_0000214.png in 18.290756702423096 seconds
# Printed stage3_0000215.png in 15.703967094421387 seconds
# Printed stage3_0000216.png in 14.400008916854858 seconds
# Printed stage3_0000217.png in 19.498149871826172 seconds
# Printed stage3_0000218.png in 16.1324679851532 seconds
# Printed stage3_0000219.png in 16.059442043304443 seconds
# Printed stage3_0000220.png in 18.21469736099243 seconds
# Printed stage3_0000221.png in 16.26233696937561 seconds
# Printed stage3_0000222.png in 15.837937116622925 seconds
# Printed stage3_0000223.png in 18.06461524963379 seconds
# Printed stage3_0000224.png in 16.550055980682373 seconds
# Printed stage3_0000225.png in 16.305163860321045 seconds
# Printed stage3_0000226.png in 17.99313187599182 seconds
# Printed stage3_0000227.png in 15.218234062194824 seconds
# Printed stage3_0000228.png in 14.24298906326294 seconds
# Printed stage3_0000229.png in 15.943589925765991 seconds
# Printed stage3_0000230.png in 14.078248977661133 seconds
# Printed stage3_0000231.png in 14.010075807571411 seconds
# Printed stage3_0000232.png in 16.0612530708313 seconds
# Printed stage3_0000233.png in 17.129122018814087 seconds
# Printed stage3_0000234.png in 13.948389053344727 seconds
# Printed stage3_0000235.png in 17.72596025466919 seconds
# Printed stage3_0000236.png in 14.736932039260864 seconds
# Printed stage3_0000237.png in 14.182955980300903 seconds
# Printed stage3_0000238.png in 15.837440967559814 seconds
# Printed stage3_0000239.png in 14.046135902404785 seconds
# Printed stage3_0000240.png in 13.728596925735474 seconds
# Printed stage3_0000241.png in 17.29777479171753 seconds
# Printed stage3_0000242.png in 15.277393817901611 seconds
# Printed stage3_0000243.png in 20.471981048583984 seconds
# Printed stage3_0000244.png in 19.94212317466736 seconds
# Printed stage3_0000245.png in 19.0628719329834 seconds
# Printed stage3_0000246.png in 19.875858068466187 seconds
# Printed stage3_0000247.png in 19.05975604057312 seconds
# Printed stage3_0000248.png in 24.139990091323853 seconds
# Printed stage3_0000249.png in 19.97115707397461 seconds
# Printed stage3_0000250.png in 21.50526213645935 seconds
# Printed stage3_0000251.png in 20.223317861557007 seconds
# Printed stage3_0000252.png in 16.170822143554688 seconds
# Printed stage3_0000253.png in 16.655691146850586 seconds
# Printed stage3_0000254.png in 18.62751317024231 seconds
# Printed stage3_0000255.png in 16.82292103767395 seconds
# Printed stage3_0000256.png in 16.409921169281006 seconds
# Printed stage3_0000257.png in 16.655891180038452 seconds
# Printed stage3_0000258.png in 21.996033191680908 seconds
# Printed stage3_0000259.png in 15.875502109527588 seconds
# Printed stage3_0000260.png in 16.045414924621582 seconds
# Printed stage3_0000261.png in 18.226379871368408 seconds
# Printed stage3_0000262.png in 16.51211380958557 seconds
# Printed stage3_0000263.png in 16.06600594520569 seconds
# Printed stage3_0000264.png in 21.957274913787842 seconds
# Printed stage3_0000265.png in 16.19882082939148 seconds
# Printed stage3_0000266.png in 16.455068349838257 seconds
# Printed stage3_0000267.png in 16.843231916427612 seconds
# Printed stage3_0000268.png in 20.00767421722412 seconds
# Printed stage3_0000269.png in 16.334455966949463 seconds
# Printed stage3_0000270.png in 15.977850198745728 seconds
# Printed stage3_0000271.png in 19.083705186843872 seconds
# Printed stage3_0000272.png in 17.01361894607544 seconds
# Printed stage3_0000273.png in 17.132532119750977 seconds
# Printed stage3_0000274.png in 18.671811819076538 seconds
# Printed stage3_0000275.png in 33.01124715805054 seconds
# Printed stage3_0000276.png in 21.882164001464844 seconds
# Printed stage3_0000277.png in 19.013427019119263 seconds
# Printed stage3_0000278.png in 20.41208004951477 seconds
# Printed stage3_0000279.png in 30.136447191238403 seconds
# Printed stage3_0000280.png in 21.018254041671753 seconds
# Printed stage3_0000281.png in 20.818828105926514 seconds
# Printed stage3_0000282.png in 32.237757205963135 seconds
# Printed stage3_0000283.png in 21.55950379371643 seconds
# Printed stage3_0000284.png in 20.36126184463501 seconds
# Printed stage3_0000285.png in 20.791531085968018 seconds
# Printed stage3_0000286.png in 35.61836791038513 seconds
# Printed stage3_0000287.png in 21.060811042785645 seconds
# Printed stage3_0000288.png in 22.021575927734375 seconds
# Printed stage3_0000289.png in 19.912478923797607 seconds
# Printed stage3_0000290.png in 38.6802659034729 seconds
# Printed stage3_0000291.png in 22.049488067626953 seconds
# Printed stage3_0000292.png in 23.362908124923706 seconds
# Printed stage3_0000293.png in 19.77833604812622 seconds
# Printed stage3_0000294.png in 35.7880539894104 seconds
# Printed stage3_0000295.png in 16.590039014816284 seconds
# Printed stage3_0000296.png in 16.76824378967285 seconds
# Printed stage3_0000297.png in 19.002769947052002 seconds
# Printed stage3_0000298.png in 16.67537212371826 seconds
# Printed stage3_0000299.png in 16.464956283569336 seconds
