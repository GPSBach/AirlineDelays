# %%
import os
import conda

conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

from mpl_toolkits.basemap import Basemap

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pygrib
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
import time

def print_time(t0):
    t1 = time.time()
    return t1-t0

# %%
# starting and ending viewazimuths
azim_start = 270
azim_end = 270

# starting and ending view elevations
elev_start = 90
elev_end = 90

# starting and ending zooms
dist_start = 300
dist_end = 300

# starting and ending center latitude
lat_start = 43
lat_end = 43

# starting and ending longitude
lon_start = -97
lon_end = -97

# starting and ending layer separation
delev_start = 0
delev_end = 0

# delta center degrees
# latitude window for center
# tradoff with dist
ddeg = 1

#save files setup
savepath = '../plots/map/movie/animation/'
filename = 'stage1_'


num_steps = 300

t0 = time.time()

variables = ['Total Cloud Cover']
colors = ['viridis']
ranges = [(0,100)]

for i in range(num_steps):
    delev = delev_start-i*((delev_start-delev_end)/(num_steps-1))
    hour = str(i-24*(i//24)).zfill(2)
    day = str(1+i//24).zfill(2)
    try:
        grbs = pygrib.open(f'../data/weather/august_full/rap_130_201808{day}_{hour}00_000.grb2')
    except:
        pass
    
    datas = []
    elev = np.arange(len(variables))*delev

    for variable in variables:
        grb = grbs.select(name=variable)[0]
        lats, lons = grb.latlons()
        datas.append(grb['values'])

    map = Basemap(llcrnrlon=-360,llcrnrlat=-90,urcrnrlon=360,urcrnrlat=90,)

    fig = plt.figure(figsize=[10,10],dpi=150)
    ax = Axes3D(fig)

    ax.add_collection3d(map.drawcoastlines(linewidth=0.25))
    ax.add_collection3d(map.drawcountries(linewidth=0.35))

    ax.set_axis_off()
    ax.azim = azim_start-i*((azim_start-azim_end)/(num_steps-1))
    ax.elev = elev_start-i*((elev_start-elev_end)/(num_steps-1))
    ax.dist = dist_start-i*((dist_start-dist_end)/(num_steps-1))
    
    center_lat = lat_start-i*((lat_start-lat_end)/(num_steps-1))
    center_lon = lon_start-i*((lon_start-lon_end)/(num_steps-1))


    for ix,data in enumerate(datas):
        # fourth dimention - colormap
        # create colormap according to x-value (can use any 50x50 array)
        color_dimension = data # change to desired fourth dimension
        minn, maxx = color_dimension.min(), color_dimension.max()
        norm = matplotlib.colors.Normalize(minn, maxx)
        m = plt.cm.ScalarMappable(norm=norm, cmap=colors[ix])
        m.set_array([])
        fcolors = m.to_rgba(color_dimension)

        ax.plot_surface(lons,lats,np.ones(lats.shape)*elev[ix]+delev/10,cstride=5,rstride=5,facecolors=fcolors, vmin=ranges[ix][0], vmax=ranges[ix][0], shade=False)

    ax.set_xlim3d(center_lon-ddeg,center_lon+ddeg)
    ax.set_ylim3d(center_lat-ddeg,center_lat+ddeg)
    if i < 10:
        fig.savefig(f'{savepath}{filename}0000{i}.png', dpi=fig.dpi)
    elif i >=10 and i < 100:
        fig.savefig(f'{savepath}{filename}000{i}.png', dpi=fig.dpi)
    elif i >=100 and i < 1000:
        fig.savefig(f'{savepath}{filename}00{i}.png', dpi=fig.dpi)
    elif i > 1000:
        fig.savefig(f'{savepath}{filename}0{i}.png', dpi=fig.dpi)
    plt.close()
    print(f'Printed {filename}0000{i}.png in',print_time(t0),'seconds')
    t0 = time.time()
# Out:
# Printed stage1_00000.png in 7.3655686378479 seconds
# Printed stage1_00001.png in 5.66997504234314 seconds
# Printed stage1_00002.png in 5.543423891067505 seconds
# Printed stage1_00003.png in 6.014303922653198 seconds
# Printed stage1_00004.png in 6.146869897842407 seconds
# Printed stage1_00005.png in 5.922309875488281 seconds
# Printed stage1_00006.png in 6.00609016418457 seconds
# Printed stage1_00007.png in 5.998108863830566 seconds
# Printed stage1_00008.png in 6.071171283721924 seconds
# Printed stage1_00009.png in 6.1865479946136475 seconds
# Printed stage1_000010.png in 6.298144817352295 seconds
# Printed stage1_000011.png in 6.533869028091431 seconds
# Printed stage1_000012.png in 6.249390125274658 seconds
# Printed stage1_000013.png in 5.872684955596924 seconds
# Printed stage1_000014.png in 5.743408918380737 seconds
# Printed stage1_000015.png in 5.843609094619751 seconds
# Printed stage1_000016.png in 5.848228216171265 seconds
# Printed stage1_000017.png in 6.799528121948242 seconds
# Printed stage1_000018.png in 6.2406699657440186 seconds
# Printed stage1_000019.png in 6.853327751159668 seconds
# Printed stage1_000020.png in 6.5668511390686035 seconds
# Printed stage1_000021.png in 6.194190979003906 seconds
# Printed stage1_000022.png in 6.336560964584351 seconds
# Printed stage1_000023.png in 5.785076856613159 seconds
# Printed stage1_000024.png in 7.667080879211426 seconds
# Printed stage1_000025.png in 6.942539215087891 seconds
# Printed stage1_000026.png in 7.7687828540802 seconds
# Printed stage1_000027.png in 6.3204450607299805 seconds
# Printed stage1_000028.png in 6.757550954818726 seconds
# Printed stage1_000029.png in 7.104253053665161 seconds
# Printed stage1_000030.png in 6.74346399307251 seconds
# Printed stage1_000031.png in 6.6220221519470215 seconds
# Printed stage1_000032.png in 6.631631135940552 seconds
# Printed stage1_000033.png in 5.995510101318359 seconds
# Printed stage1_000034.png in 6.102848052978516 seconds
# Printed stage1_000035.png in 7.7277302742004395 seconds
# Printed stage1_000036.png in 6.5152881145477295 seconds
# Printed stage1_000037.png in 6.38120698928833 seconds
# Printed stage1_000038.png in 6.880891799926758 seconds
# Printed stage1_000039.png in 6.165532827377319 seconds
# Printed stage1_000040.png in 6.695779085159302 seconds
# Printed stage1_000041.png in 6.230077266693115 seconds
# Printed stage1_000042.png in 6.87839412689209 seconds
# Printed stage1_000043.png in 7.212759971618652 seconds
# Printed stage1_000044.png in 6.745807886123657 seconds
# Printed stage1_000045.png in 6.619239807128906 seconds
# Printed stage1_000046.png in 9.230006217956543 seconds
# Printed stage1_000047.png in 10.684436082839966 seconds
# Printed stage1_000048.png in 10.541661977767944 seconds
# Printed stage1_000049.png in 13.321305990219116 seconds
# Printed stage1_000050.png in 11.666857242584229 seconds
# Printed stage1_000051.png in 9.777136087417603 seconds
# Printed stage1_000052.png in 8.200923919677734 seconds
# Printed stage1_000053.png in 8.473469018936157 seconds
# Printed stage1_000054.png in 7.613168716430664 seconds
# Printed stage1_000055.png in 7.805391073226929 seconds
# Printed stage1_000056.png in 7.70789909362793 seconds
# Printed stage1_000057.png in 12.065845012664795 seconds
# Printed stage1_000058.png in 8.111479759216309 seconds
# Printed stage1_000059.png in 8.56254529953003 seconds
# Printed stage1_000060.png in 8.89987826347351 seconds
# Printed stage1_000061.png in 8.54237699508667 seconds
# Printed stage1_000062.png in 8.166280031204224 seconds
# Printed stage1_000063.png in 8.303544044494629 seconds
# Printed stage1_000064.png in 8.601265907287598 seconds
# Printed stage1_000065.png in 9.048741817474365 seconds
# Printed stage1_000066.png in 7.752295017242432 seconds
# Printed stage1_000067.png in 7.694246768951416 seconds
# Printed stage1_000068.png in 9.184134244918823 seconds
# Printed stage1_000069.png in 8.778541088104248 seconds
# Printed stage1_000070.png in 8.22318410873413 seconds
# Printed stage1_000071.png in 7.804688930511475 seconds
# Printed stage1_000072.png in 9.173620223999023 seconds
# Printed stage1_000073.png in 8.267747163772583 seconds
# Printed stage1_000074.png in 6.920098066329956 seconds
# Printed stage1_000075.png in 5.604755163192749 seconds
# Printed stage1_000076.png in 5.83024787902832 seconds
# Printed stage1_000077.png in 5.979482173919678 seconds
# Printed stage1_000078.png in 5.936656951904297 seconds
# Printed stage1_000079.png in 6.549968957901001 seconds
# Printed stage1_000080.png in 6.408919095993042 seconds
# Printed stage1_000081.png in 5.975793361663818 seconds
# Printed stage1_000082.png in 6.594604730606079 seconds
# Printed stage1_000083.png in 6.42981219291687 seconds
# Printed stage1_000084.png in 6.599085807800293 seconds
# Printed stage1_000085.png in 6.4839489459991455 seconds
# Printed stage1_000086.png in 6.206212043762207 seconds
# Printed stage1_000087.png in 6.791192054748535 seconds
# Printed stage1_000088.png in 6.762423038482666 seconds
# Printed stage1_000089.png in 6.946089029312134 seconds
# Printed stage1_000090.png in 6.511115074157715 seconds
# Printed stage1_000091.png in 6.696423768997192 seconds
# Printed stage1_000092.png in 7.215691804885864 seconds
# Printed stage1_000093.png in 7.402189016342163 seconds
# Printed stage1_000094.png in 8.010419130325317 seconds
# Printed stage1_000095.png in 7.0988781452178955 seconds
# Printed stage1_000096.png in 8.020854949951172 seconds
# Printed stage1_000097.png in 7.563732862472534 seconds
# Printed stage1_000098.png in 8.945791959762573 seconds
# Printed stage1_000099.png in 8.879854202270508 seconds
# Printed stage1_0000100.png in 9.80454421043396 seconds
# Printed stage1_0000101.png in 6.914723634719849 seconds
# Printed stage1_0000102.png in 7.8931519985198975 seconds
# Printed stage1_0000103.png in 7.330950736999512 seconds
# Printed stage1_0000104.png in 6.969829082489014 seconds
# Printed stage1_0000105.png in 7.512315034866333 seconds
# Printed stage1_0000106.png in 7.2811901569366455 seconds
# Printed stage1_0000107.png in 7.167041063308716 seconds
# Printed stage1_0000108.png in 6.878843784332275 seconds
# Printed stage1_0000109.png in 7.69127893447876 seconds
# Printed stage1_0000110.png in 6.889101982116699 seconds
# Printed stage1_0000111.png in 7.902871131896973 seconds
# Printed stage1_0000112.png in 7.538227081298828 seconds
# Printed stage1_0000113.png in 7.264916181564331 seconds
# Printed stage1_0000114.png in 5.659793138504028 seconds
# Printed stage1_0000115.png in 6.419603109359741 seconds
# Printed stage1_0000116.png in 5.81889796257019 seconds
# Printed stage1_0000117.png in 6.107438802719116 seconds
# Printed stage1_0000118.png in 5.613607883453369 seconds
# Printed stage1_0000119.png in 5.579380035400391 seconds
# Printed stage1_0000120.png in 5.692758083343506 seconds
# Printed stage1_0000121.png in 5.828793287277222 seconds
# Printed stage1_0000122.png in 6.059323072433472 seconds
# Printed stage1_0000123.png in 5.735720872879028 seconds
# Printed stage1_0000124.png in 6.281408071517944 seconds
# Printed stage1_0000125.png in 6.05779504776001 seconds
# Printed stage1_0000126.png in 6.947465896606445 seconds
# Printed stage1_0000127.png in 6.033077955245972 seconds
# Printed stage1_0000128.png in 5.429713010787964 seconds
# Printed stage1_0000129.png in 5.980417013168335 seconds
# Printed stage1_0000130.png in 5.6728010177612305 seconds
# Printed stage1_0000131.png in 6.154778242111206 seconds
# Printed stage1_0000132.png in 5.614483118057251 seconds
# Printed stage1_0000133.png in 6.498220205307007 seconds
# Printed stage1_0000134.png in 5.501484155654907 seconds
# Printed stage1_0000135.png in 5.385354995727539 seconds
# Printed stage1_0000136.png in 6.177402973175049 seconds
# Printed stage1_0000137.png in 5.743887901306152 seconds
# Printed stage1_0000138.png in 5.732682943344116 seconds
# Printed stage1_0000139.png in 6.229696989059448 seconds
# Printed stage1_0000140.png in 6.037095069885254 seconds
# Printed stage1_0000141.png in 6.676932096481323 seconds
# Printed stage1_0000142.png in 6.694165945053101 seconds
# Printed stage1_0000143.png in 7.028897047042847 seconds
# Printed stage1_0000144.png in 7.7973010540008545 seconds
# Printed stage1_0000145.png in 6.971831798553467 seconds
# Printed stage1_0000146.png in 6.2642340660095215 seconds
# Printed stage1_0000147.png in 6.3399457931518555 seconds
# Printed stage1_0000148.png in 5.53263783454895 seconds
# Printed stage1_0000149.png in 5.4634387493133545 seconds
# Printed stage1_0000150.png in 6.3169190883636475 seconds
# Printed stage1_0000151.png in 6.045408248901367 seconds
# Printed stage1_0000152.png in 5.878676176071167 seconds
# Printed stage1_0000153.png in 6.372253179550171 seconds
# Printed stage1_0000154.png in 5.934624910354614 seconds
# Printed stage1_0000155.png in 5.855690956115723 seconds
# Printed stage1_0000156.png in 6.255988836288452 seconds
# Printed stage1_0000157.png in 5.8335559368133545 seconds
# Printed stage1_0000158.png in 6.186277866363525 seconds
# Printed stage1_0000159.png in 6.142461061477661 seconds
# Printed stage1_0000160.png in 6.145997762680054 seconds
# Printed stage1_0000161.png in 6.4390869140625 seconds
# Printed stage1_0000162.png in 5.990973949432373 seconds
# Printed stage1_0000163.png in 6.098433017730713 seconds
# Printed stage1_0000164.png in 6.328073978424072 seconds
# Printed stage1_0000165.png in 5.601596832275391 seconds
# Printed stage1_0000166.png in 5.950456142425537 seconds
# Printed stage1_0000167.png in 5.44697904586792 seconds
# Printed stage1_0000168.png in 6.108659982681274 seconds
# Printed stage1_0000169.png in 5.637912034988403 seconds
# Printed stage1_0000170.png in 5.689600944519043 seconds
# Printed stage1_0000171.png in 6.691006898880005 seconds
# Printed stage1_0000172.png in 6.781302213668823 seconds
# Printed stage1_0000173.png in 7.287710905075073 seconds
# Printed stage1_0000174.png in 8.06665325164795 seconds
# Printed stage1_0000175.png in 7.037137985229492 seconds
# Printed stage1_0000176.png in 6.768203973770142 seconds
# Printed stage1_0000177.png in 6.7719831466674805 seconds
# Printed stage1_0000178.png in 5.675809144973755 seconds
# Printed stage1_0000179.png in 5.5223939418792725 seconds
# Printed stage1_0000180.png in 6.974302053451538 seconds
# Printed stage1_0000181.png in 6.4539408683776855 seconds
# Printed stage1_0000182.png in 5.906493186950684 seconds
# Printed stage1_0000183.png in 6.021255254745483 seconds
# Printed stage1_0000184.png in 6.8668811321258545 seconds
# Printed stage1_0000185.png in 6.177908897399902 seconds
# Printed stage1_0000186.png in 5.676353931427002 seconds
# Printed stage1_0000187.png in 7.776417016983032 seconds
# Printed stage1_0000188.png in 6.682133913040161 seconds
# Printed stage1_0000189.png in 6.588283061981201 seconds
# Printed stage1_0000190.png in 7.176022052764893 seconds
# Printed stage1_0000191.png in 5.971005916595459 seconds
# Printed stage1_0000192.png in 7.337455987930298 seconds
# Printed stage1_0000193.png in 8.25662088394165 seconds
# Printed stage1_0000194.png in 9.41231393814087 seconds
# Printed stage1_0000195.png in 6.851055145263672 seconds
# Printed stage1_0000196.png in 7.137901067733765 seconds
# Printed stage1_0000197.png in 6.89423680305481 seconds
# Printed stage1_0000198.png in 6.59097695350647 seconds
# Printed stage1_0000199.png in 5.6973090171813965 seconds
# Printed stage1_0000200.png in 6.429248094558716 seconds
# Printed stage1_0000201.png in 7.3119261264801025 seconds
# Printed stage1_0000202.png in 6.144682884216309 seconds
# Printed stage1_0000203.png in 5.673923969268799 seconds
# Printed stage1_0000204.png in 5.577695846557617 seconds
# Printed stage1_0000205.png in 6.795220375061035 seconds
# Printed stage1_0000206.png in 6.74046516418457 seconds
# Printed stage1_0000207.png in 6.724956035614014 seconds
# Printed stage1_0000208.png in 6.629831314086914 seconds
# Printed stage1_0000209.png in 7.156172037124634 seconds
# Printed stage1_0000210.png in 6.613756895065308 seconds
# Printed stage1_0000211.png in 6.592720031738281 seconds
# Printed stage1_0000212.png in 6.911687850952148 seconds
# Printed stage1_0000213.png in 6.225398063659668 seconds
# Printed stage1_0000214.png in 6.6327149868011475 seconds
# Printed stage1_0000215.png in 5.982363700866699 seconds
# Printed stage1_0000216.png in 7.385096073150635 seconds
# Printed stage1_0000217.png in 6.512244939804077 seconds
# Printed stage1_0000218.png in 6.394547939300537 seconds
# Printed stage1_0000219.png in 6.423691034317017 seconds
# Printed stage1_0000220.png in 7.709801912307739 seconds
# Printed stage1_0000221.png in 8.579960823059082 seconds
# Printed stage1_0000222.png in 7.52782416343689 seconds
# Printed stage1_0000223.png in 7.28278923034668 seconds
# Printed stage1_0000224.png in 8.692886114120483 seconds
# Printed stage1_0000225.png in 6.712855815887451 seconds
# Printed stage1_0000226.png in 6.448930740356445 seconds
# Printed stage1_0000227.png in 6.395501136779785 seconds
# Printed stage1_0000228.png in 6.406935930252075 seconds
# Printed stage1_0000229.png in 7.903737783432007 seconds
# Printed stage1_0000230.png in 6.089158296585083 seconds
# Printed stage1_0000231.png in 6.61045503616333 seconds
# Printed stage1_0000232.png in 7.204848051071167 seconds
# Printed stage1_0000233.png in 8.305839776992798 seconds
# Printed stage1_0000234.png in 7.165116786956787 seconds
# Printed stage1_0000235.png in 6.338536739349365 seconds
# Printed stage1_0000236.png in 7.688943147659302 seconds
# Printed stage1_0000237.png in 8.734503984451294 seconds
# Printed stage1_0000238.png in 6.151349067687988 seconds
# Printed stage1_0000239.png in 5.581529140472412 seconds
# Printed stage1_0000240.png in 5.572553873062134 seconds
# Printed stage1_0000241.png in 6.355170011520386 seconds
# Printed stage1_0000242.png in 5.48206901550293 seconds
# Printed stage1_0000243.png in 5.69312596321106 seconds
# Printed stage1_0000244.png in 5.294674873352051 seconds
# Printed stage1_0000245.png in 5.534284830093384 seconds
# Printed stage1_0000246.png in 6.116301774978638 seconds
# Printed stage1_0000247.png in 5.429156064987183 seconds
# Printed stage1_0000248.png in 5.45388388633728 seconds
# Printed stage1_0000249.png in 5.471056222915649 seconds
# Printed stage1_0000250.png in 6.254701137542725 seconds
# Printed stage1_0000251.png in 5.539623022079468 seconds
# Printed stage1_0000252.png in 5.627600908279419 seconds
# Printed stage1_0000253.png in 5.3755481243133545 seconds
# Printed stage1_0000254.png in 5.511464834213257 seconds
# Printed stage1_0000255.png in 6.4573822021484375 seconds
# Printed stage1_0000256.png in 5.509428977966309 seconds
# Printed stage1_0000257.png in 5.568741083145142 seconds
# Printed stage1_0000258.png in 5.422978639602661 seconds
# Printed stage1_0000259.png in 5.2468039989471436 seconds
# Printed stage1_0000260.png in 6.422122001647949 seconds
# Printed stage1_0000261.png in 5.408434867858887 seconds
# Printed stage1_0000262.png in 5.3426947593688965 seconds
# Printed stage1_0000263.png in 5.124402284622192 seconds
# Printed stage1_0000264.png in 7.265844106674194 seconds
# Printed stage1_0000265.png in 6.70914101600647 seconds
# Printed stage1_0000266.png in 6.667575120925903 seconds
# Printed stage1_0000267.png in 6.508378267288208 seconds
# Printed stage1_0000268.png in 5.52547812461853 seconds
# Printed stage1_0000269.png in 6.6616387367248535 seconds
# Printed stage1_0000270.png in 6.303970098495483 seconds
# Printed stage1_0000271.png in 6.329990863800049 seconds
# Printed stage1_0000272.png in 6.842008113861084 seconds
# Printed stage1_0000273.png in 6.739904880523682 seconds
# Printed stage1_0000274.png in 7.240047931671143 seconds
# Printed stage1_0000275.png in 6.423557758331299 seconds
# Printed stage1_0000276.png in 7.004356145858765 seconds
# Printed stage1_0000277.png in 5.9872589111328125 seconds
# Printed stage1_0000278.png in 6.11952805519104 seconds
# Printed stage1_0000279.png in 7.6572558879852295 seconds
# Printed stage1_0000280.png in 6.251800060272217 seconds
# Printed stage1_0000281.png in 6.516765356063843 seconds
# Printed stage1_0000282.png in 6.764164924621582 seconds
# Printed stage1_0000283.png in 6.36539888381958 seconds
# Printed stage1_0000284.png in 6.351515054702759 seconds
# Printed stage1_0000285.png in 7.569993019104004 seconds
# Printed stage1_0000286.png in 6.65886378288269 seconds
# Printed stage1_0000287.png in 5.903378009796143 seconds
# Printed stage1_0000288.png in 6.26917290687561 seconds
# Printed stage1_0000289.png in 6.584135293960571 seconds
# Printed stage1_0000290.png in 7.585330009460449 seconds
# Printed stage1_0000291.png in 7.161025047302246 seconds
# Printed stage1_0000292.png in 6.459500074386597 seconds
# Printed stage1_0000293.png in 6.722150802612305 seconds
# Printed stage1_0000294.png in 7.789760112762451 seconds
# Printed stage1_0000295.png in 9.386974096298218 seconds
# Printed stage1_0000296.png in 6.847115993499756 seconds
# Printed stage1_0000297.png in 7.0074968338012695 seconds
# Printed stage1_0000298.png in 7.876518964767456 seconds
# Printed stage1_0000299.png in 7.621982097625732 seconds
