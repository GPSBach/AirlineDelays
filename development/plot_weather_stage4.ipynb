# %%
import os
import conda

conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

from mpl_toolkits.basemap import Basemap

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pygrib
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
import time

def print_time(t0):
    t1 = time.time()
    return t1-t0

# %%
# starting and ending viewazimuths
azim_start = 200
azim_end = 270

# starting and ending view elevations
elev_start = 30
elev_end = 90

# starting and ending zooms
dist_start = 250
dist_end = 230

# starting and ending center latitude
lat_start = 50
lat_end = 38.5

# starting and ending longitude
lon_start = -80
lon_end = -97.5

# starting and ending layer separation
delev_start = 5
delev_end = 0

# delta center degrees
# latitude window for center
# tradoff with dist
ddeg = 1

#save files setup
savepath = '../plots/map/movie/animation/'
filename = 'stage4_'


num_steps = 300

t0 = time.time()

variables = ['Wind speed (gust)','Visibility','Maximum/Composite radar reflectivity','Total Cloud Cover']
colors = ['viridis','magma','jet','viridis']
ranges = [(0,10),(0,90000),(-10,50),(0,100)]

for i in range(num_steps):
    delev = delev_start-i*((delev_start-delev_end)/(num_steps-1))
    hour = str(i-24*(i//24)).zfill(2)
    day = str(1+i//24).zfill(2)
    try:
        grbs = pygrib.open(f'../data/weather/august_full/rap_130_201808{day}_{hour}00_000.grb2')
    except:
        pass
    
    datas = []
    elev = np.arange(len(variables))*delev

    for variable in variables:
        grb = grbs.select(name=variable)[0]
        lats, lons = grb.latlons()
        datas.append(grb['values'])

    map = Basemap(llcrnrlon=-360,llcrnrlat=-90,urcrnrlon=360,urcrnrlat=90,)

    fig = plt.figure(figsize=[10,10],dpi=150)
    ax = Axes3D(fig)

    ax.add_collection3d(map.drawcoastlines(linewidth=0.25))
    ax.add_collection3d(map.drawcountries(linewidth=0.35))

    ax.set_axis_off()
    ax.azim = azim_start-i*((azim_start-azim_end)/(num_steps-1))
    ax.elev = elev_start-i*((elev_start-elev_end)/(num_steps-1))
    ax.dist = dist_start-i*((dist_start-dist_end)/(num_steps-1))
    
    center_lat = lat_start-i*((lat_start-lat_end)/(num_steps-1))
    center_lon = lon_start-i*((lon_start-lon_end)/(num_steps-1))


    for ix,data in enumerate(datas):
        # fourth dimention - colormap
        # create colormap according to x-value (can use any 50x50 array)
        color_dimension = data # change to desired fourth dimension
        minn, maxx = color_dimension.min(), color_dimension.max()
        norm = matplotlib.colors.Normalize(minn, maxx)
        m = plt.cm.ScalarMappable(norm=norm, cmap=colors[ix])
        m.set_array([])
        fcolors = m.to_rgba(color_dimension)

        ax.plot_surface(lons,lats,np.ones(lats.shape)*elev[ix]+delev/10,cstride=5,rstride=5,facecolors=fcolors, vmin=ranges[ix][0], vmax=ranges[ix][0], shade=False)

    ax.set_xlim3d(center_lon-ddeg,center_lon+ddeg)
    ax.set_ylim3d(center_lat-ddeg,center_lat+ddeg)
    if i < 10:
        fig.savefig(f'{savepath}{filename}0000{i}.png', dpi=fig.dpi)
    elif i >=10 and i < 100:
        fig.savefig(f'{savepath}{filename}000{i}.png', dpi=fig.dpi)
    elif i >=100 and i < 1000:
        fig.savefig(f'{savepath}{filename}00{i}.png', dpi=fig.dpi)
    elif i > 1000:
        fig.savefig(f'{savepath}{filename}0{i}.png', dpi=fig.dpi)
    plt.close()
    print(f'Printed {filename}0000{i}.png in',print_time(t0),'seconds')
    t0 = time.time()
# Out:
# Printed stage4_00000.png in 24.437241792678833 seconds
# Printed stage4_00001.png in 17.74995183944702 seconds
# Printed stage4_00002.png in 19.7988178730011 seconds
# Printed stage4_00003.png in 20.1268367767334 seconds
# Printed stage4_00004.png in 19.47058367729187 seconds
# Printed stage4_00005.png in 21.341885805130005 seconds
# Printed stage4_00006.png in 20.329293251037598 seconds
# Printed stage4_00007.png in 22.448564052581787 seconds
# Printed stage4_00008.png in 19.04264235496521 seconds
# Printed stage4_00009.png in 17.39690589904785 seconds
# Printed stage4_000010.png in 17.667196035385132 seconds
# Printed stage4_000011.png in 17.1266770362854 seconds
# Printed stage4_000012.png in 18.306071043014526 seconds
# Printed stage4_000013.png in 17.192451000213623 seconds
# Printed stage4_000014.png in 17.122626066207886 seconds
# Printed stage4_000015.png in 18.279819011688232 seconds
# Printed stage4_000016.png in 16.877269744873047 seconds
# Printed stage4_000017.png in 16.672724962234497 seconds
# Printed stage4_000018.png in 16.774399042129517 seconds
# Printed stage4_000019.png in 18.0734920501709 seconds
# Printed stage4_000020.png in 17.0287868976593 seconds
# Printed stage4_000021.png in 17.38901400566101 seconds
# Printed stage4_000022.png in 17.79981303215027 seconds
# Printed stage4_000023.png in 16.578215837478638 seconds
# Printed stage4_000024.png in 17.625702142715454 seconds
# Printed stage4_000025.png in 16.96558403968811 seconds
# Printed stage4_000026.png in 17.48163914680481 seconds
# Printed stage4_000027.png in 16.700366020202637 seconds
# Printed stage4_000028.png in 17.25554895401001 seconds
# Printed stage4_000029.png in 17.642556190490723 seconds
# Printed stage4_000030.png in 17.507879972457886 seconds
# Printed stage4_000031.png in 19.29038095474243 seconds
# Printed stage4_000032.png in 20.43379497528076 seconds
# Printed stage4_000033.png in 27.9844331741333 seconds
# Printed stage4_000034.png in 20.509598970413208 seconds
# Printed stage4_000035.png in 20.382580280303955 seconds
# Printed stage4_000036.png in 21.506190061569214 seconds
# Printed stage4_000037.png in 21.15530776977539 seconds
# Printed stage4_000038.png in 20.70896291732788 seconds
# Printed stage4_000039.png in 21.397212743759155 seconds
# Printed stage4_000040.png in 22.076336145401 seconds
# Printed stage4_000041.png in 21.88660478591919 seconds
# Printed stage4_000042.png in 21.438637733459473 seconds
# Printed stage4_000043.png in 21.540650129318237 seconds
# Printed stage4_000044.png in 22.45633292198181 seconds
# Printed stage4_000045.png in 21.915314197540283 seconds
# Printed stage4_000046.png in 23.175899982452393 seconds
# Printed stage4_000047.png in 20.4006130695343 seconds
# Printed stage4_000048.png in 20.887786865234375 seconds
# Printed stage4_000049.png in 24.852378845214844 seconds
# Printed stage4_000050.png in 23.272439002990723 seconds
# Printed stage4_000051.png in 23.583730220794678 seconds
# Printed stage4_000052.png in 19.959859132766724 seconds
# Printed stage4_000053.png in 21.55898404121399 seconds
# Printed stage4_000054.png in 22.77347707748413 seconds
# Printed stage4_000055.png in 17.125173091888428 seconds
# Printed stage4_000056.png in 17.1476571559906 seconds
# Printed stage4_000057.png in 17.012776851654053 seconds
# Printed stage4_000058.png in 17.639233827590942 seconds
# Printed stage4_000059.png in 17.195125102996826 seconds
# Printed stage4_000060.png in 14.533220052719116 seconds
# Printed stage4_000061.png in 14.605045080184937 seconds
# Printed stage4_000062.png in 14.596495151519775 seconds
# Printed stage4_000063.png in 14.845466136932373 seconds
# Printed stage4_000064.png in 14.169651746749878 seconds
# Printed stage4_000065.png in 14.132004737854004 seconds
# Printed stage4_000066.png in 14.476351022720337 seconds
# Printed stage4_000067.png in 17.10690402984619 seconds
# Printed stage4_000068.png in 14.71787714958191 seconds
# Printed stage4_000069.png in 14.847544193267822 seconds
# Printed stage4_000070.png in 14.87688398361206 seconds
# Printed stage4_000071.png in 15.077301740646362 seconds
# Printed stage4_000072.png in 15.214422941207886 seconds
# Printed stage4_000073.png in 16.749674081802368 seconds
# Printed stage4_000074.png in 14.727592945098877 seconds
# Printed stage4_000075.png in 15.405719995498657 seconds
# Printed stage4_000076.png in 16.144517183303833 seconds
# Printed stage4_000077.png in 15.462090015411377 seconds
# Printed stage4_000078.png in 15.866091012954712 seconds
# Printed stage4_000079.png in 14.599885940551758 seconds
# Printed stage4_000080.png in 14.830996990203857 seconds
# Printed stage4_000081.png in 14.847562313079834 seconds
# Printed stage4_000082.png in 14.079228162765503 seconds
# Printed stage4_000083.png in 14.72599196434021 seconds
# Printed stage4_000084.png in 14.730584621429443 seconds
# Printed stage4_000085.png in 14.848071813583374 seconds
# Printed stage4_000086.png in 14.935370922088623 seconds
# Printed stage4_000087.png in 14.759934186935425 seconds
# Printed stage4_000088.png in 15.812402963638306 seconds
# Printed stage4_000089.png in 14.39656400680542 seconds
# Printed stage4_000090.png in 15.089555263519287 seconds
# Printed stage4_000091.png in 15.073436975479126 seconds
# Printed stage4_000092.png in 14.697261095046997 seconds
# Printed stage4_000093.png in 14.843540906906128 seconds
# Printed stage4_000094.png in 14.217439889907837 seconds
# Printed stage4_000095.png in 14.70855188369751 seconds
# Printed stage4_000096.png in 15.361430883407593 seconds
# Printed stage4_000097.png in 15.159448146820068 seconds
# Printed stage4_000098.png in 14.239634037017822 seconds
# Printed stage4_000099.png in 14.899103879928589 seconds
# Printed stage4_0000100.png in 15.196712255477905 seconds
# Printed stage4_0000101.png in 15.040527105331421 seconds
# Printed stage4_0000102.png in 14.389220714569092 seconds
# Printed stage4_0000103.png in 15.482130289077759 seconds
# Printed stage4_0000104.png in 15.404353141784668 seconds
# Printed stage4_0000105.png in 14.064785957336426 seconds
# Printed stage4_0000106.png in 15.244792938232422 seconds
# Printed stage4_0000107.png in 15.79965591430664 seconds
# Printed stage4_0000108.png in 16.200726985931396 seconds
# Printed stage4_0000109.png in 14.039154291152954 seconds
# Printed stage4_0000110.png in 16.605781078338623 seconds
# Printed stage4_0000111.png in 15.118755102157593 seconds
# Printed stage4_0000112.png in 13.552424907684326 seconds
# Printed stage4_0000113.png in 14.065533876419067 seconds
# Printed stage4_0000114.png in 13.94499683380127 seconds
# Printed stage4_0000115.png in 13.098554134368896 seconds
# Printed stage4_0000116.png in 13.971728086471558 seconds
# Printed stage4_0000117.png in 13.156385898590088 seconds
# Printed stage4_0000118.png in 13.949592113494873 seconds
# Printed stage4_0000119.png in 13.683964967727661 seconds
# Printed stage4_0000120.png in 12.90225601196289 seconds
# Printed stage4_0000121.png in 13.755250930786133 seconds
# Printed stage4_0000122.png in 13.740823030471802 seconds
# Printed stage4_0000123.png in 13.091655731201172 seconds
# Printed stage4_0000124.png in 13.69568681716919 seconds
# Printed stage4_0000125.png in 13.059417963027954 seconds
# Printed stage4_0000126.png in 13.735702991485596 seconds
# Printed stage4_0000127.png in 13.911046981811523 seconds
# Printed stage4_0000128.png in 13.109246969223022 seconds
# Printed stage4_0000129.png in 13.762378931045532 seconds
# Printed stage4_0000130.png in 13.131725072860718 seconds
# Printed stage4_0000131.png in 14.05460000038147 seconds
# Printed stage4_0000132.png in 12.779606103897095 seconds
# Printed stage4_0000133.png in 14.048435926437378 seconds
# Printed stage4_0000134.png in 12.803457736968994 seconds
# Printed stage4_0000135.png in 13.933443784713745 seconds
# Printed stage4_0000136.png in 12.439748048782349 seconds
# Printed stage4_0000137.png in 10.762259006500244 seconds
# Printed stage4_0000138.png in 11.730695962905884 seconds
# Printed stage4_0000139.png in 10.957047939300537 seconds
# Printed stage4_0000140.png in 11.832390785217285 seconds
# Printed stage4_0000141.png in 10.729572296142578 seconds
# Printed stage4_0000142.png in 11.754915952682495 seconds
# Printed stage4_0000143.png in 10.48177719116211 seconds
# Printed stage4_0000144.png in 11.72844386100769 seconds
# Printed stage4_0000145.png in 10.876720190048218 seconds
# Printed stage4_0000146.png in 11.960874080657959 seconds
# Printed stage4_0000147.png in 10.746382236480713 seconds
# Printed stage4_0000148.png in 11.849900960922241 seconds
# Printed stage4_0000149.png in 10.83828592300415 seconds
# Printed stage4_0000150.png in 12.079882860183716 seconds
# Printed stage4_0000151.png in 10.853239059448242 seconds
# Printed stage4_0000152.png in 12.208103895187378 seconds
# Printed stage4_0000153.png in 10.933307886123657 seconds
# Printed stage4_0000154.png in 11.861546277999878 seconds
# Printed stage4_0000155.png in 11.319100856781006 seconds
# Printed stage4_0000156.png in 11.836162090301514 seconds
# Printed stage4_0000157.png in 10.82638168334961 seconds
# Printed stage4_0000158.png in 11.806214094161987 seconds
# Printed stage4_0000159.png in 10.800678730010986 seconds
# Printed stage4_0000160.png in 11.806591033935547 seconds
# Printed stage4_0000161.png in 10.833398818969727 seconds
# Printed stage4_0000162.png in 11.981704950332642 seconds
# Printed stage4_0000163.png in 11.212111949920654 seconds
# Printed stage4_0000164.png in 15.09999418258667 seconds
# Printed stage4_0000165.png in 11.585160970687866 seconds
# Printed stage4_0000166.png in 11.125595808029175 seconds
# Printed stage4_0000167.png in 11.693142890930176 seconds
# Printed stage4_0000168.png in 10.875638008117676 seconds
# Printed stage4_0000169.png in 12.042439937591553 seconds
# Printed stage4_0000170.png in 10.876986265182495 seconds
# Printed stage4_0000171.png in 12.027469873428345 seconds
# Printed stage4_0000172.png in 10.934701919555664 seconds
# Printed stage4_0000173.png in 11.941763162612915 seconds
# Printed stage4_0000174.png in 10.939286231994629 seconds
# Printed stage4_0000175.png in 10.904247999191284 seconds
# Printed stage4_0000176.png in 12.110960960388184 seconds
# Printed stage4_0000177.png in 11.160964012145996 seconds
# Printed stage4_0000178.png in 12.520968914031982 seconds
# Printed stage4_0000179.png in 11.236581087112427 seconds
# Printed stage4_0000180.png in 12.473351001739502 seconds
# Printed stage4_0000181.png in 11.033199071884155 seconds
# Printed stage4_0000182.png in 15.342742204666138 seconds
# Printed stage4_0000183.png in 15.082097291946411 seconds
# Printed stage4_0000184.png in 10.88713788986206 seconds
# Printed stage4_0000185.png in 12.331998109817505 seconds
# Printed stage4_0000186.png in 10.879655838012695 seconds
# Printed stage4_0000187.png in 11.5645272731781 seconds
# Printed stage4_0000188.png in 13.922832250595093 seconds
# Printed stage4_0000189.png in 13.108817100524902 seconds
# Printed stage4_0000190.png in 12.959455966949463 seconds
# Printed stage4_0000191.png in 10.903334379196167 seconds
# Printed stage4_0000192.png in 11.248245000839233 seconds
# Printed stage4_0000193.png in 12.503556966781616 seconds
# Printed stage4_0000194.png in 11.274657011032104 seconds
# Printed stage4_0000195.png in 13.213734865188599 seconds
# Printed stage4_0000196.png in 11.577685117721558 seconds
# Printed stage4_0000197.png in 11.447943925857544 seconds
# Printed stage4_0000198.png in 12.477333068847656 seconds
# Printed stage4_0000199.png in 11.547852039337158 seconds
# Printed stage4_0000200.png in 11.416321992874146 seconds
# Printed stage4_0000201.png in 13.808833122253418 seconds
# Printed stage4_0000202.png in 14.566001176834106 seconds
# Printed stage4_0000203.png in 13.788264036178589 seconds
# Printed stage4_0000204.png in 11.189913749694824 seconds
# Printed stage4_0000205.png in 11.183520078659058 seconds
# Printed stage4_0000206.png in 12.825969934463501 seconds
# Printed stage4_0000207.png in 11.961825132369995 seconds
# Printed stage4_0000208.png in 11.801819086074829 seconds
# Printed stage4_0000209.png in 12.536834239959717 seconds
# Printed stage4_0000210.png in 11.206401824951172 seconds
# Printed stage4_0000211.png in 13.111202001571655 seconds
# Printed stage4_0000212.png in 12.571676969528198 seconds
# Printed stage4_0000213.png in 12.953166007995605 seconds
# Printed stage4_0000214.png in 15.064351081848145 seconds
# Printed stage4_0000215.png in 12.060158252716064 seconds
# Printed stage4_0000216.png in 12.5671067237854 seconds
# Printed stage4_0000217.png in 13.753761053085327 seconds
# Printed stage4_0000218.png in 15.59071397781372 seconds
# Printed stage4_0000219.png in 13.441224098205566 seconds
# Printed stage4_0000220.png in 13.592689752578735 seconds
# Printed stage4_0000221.png in 12.092698812484741 seconds
# Printed stage4_0000222.png in 12.819119930267334 seconds
# Printed stage4_0000223.png in 14.198535203933716 seconds
# Printed stage4_0000224.png in 11.736116886138916 seconds
# Printed stage4_0000225.png in 11.602941989898682 seconds
# Printed stage4_0000226.png in 13.497673034667969 seconds
# Printed stage4_0000227.png in 11.986744165420532 seconds
# Printed stage4_0000228.png in 13.979501962661743 seconds
# Printed stage4_0000229.png in 14.923115015029907 seconds
# Printed stage4_0000230.png in 13.035845041275024 seconds
# Printed stage4_0000231.png in 12.030156135559082 seconds
# Printed stage4_0000232.png in 15.435022115707397 seconds
# Printed stage4_0000233.png in 12.102859020233154 seconds
# Printed stage4_0000234.png in 11.917526960372925 seconds
# Printed stage4_0000235.png in 13.20668911933899 seconds
# Printed stage4_0000236.png in 12.198036909103394 seconds
# Printed stage4_0000237.png in 11.625125885009766 seconds
# Printed stage4_0000238.png in 13.051953077316284 seconds
# Printed stage4_0000239.png in 11.34008502960205 seconds
# Printed stage4_0000240.png in 11.491744041442871 seconds
# Printed stage4_0000241.png in 13.256752967834473 seconds
# Printed stage4_0000242.png in 11.341444969177246 seconds
# Printed stage4_0000243.png in 11.459053039550781 seconds
# Printed stage4_0000244.png in 13.14145803451538 seconds
# Printed stage4_0000245.png in 11.559800148010254 seconds
# Printed stage4_0000246.png in 11.531409978866577 seconds
# Printed stage4_0000247.png in 11.426024913787842 seconds
# Printed stage4_0000248.png in 13.05827522277832 seconds
# Printed stage4_0000249.png in 11.253325939178467 seconds
# Printed stage4_0000250.png in 11.621712923049927 seconds
# Printed stage4_0000251.png in 13.116641998291016 seconds
# Printed stage4_0000252.png in 11.44359302520752 seconds
# Printed stage4_0000253.png in 11.814709186553955 seconds
# Printed stage4_0000254.png in 14.232377767562866 seconds
# Printed stage4_0000255.png in 13.22393798828125 seconds
# Printed stage4_0000256.png in 12.26570987701416 seconds
# Printed stage4_0000257.png in 11.449657917022705 seconds
# Printed stage4_0000258.png in 13.099002122879028 seconds
# Printed stage4_0000259.png in 11.906102895736694 seconds
# Printed stage4_0000260.png in 11.454545021057129 seconds
# Printed stage4_0000261.png in 14.404451131820679 seconds
# Printed stage4_0000262.png in 12.044270038604736 seconds
# Printed stage4_0000263.png in 11.636849880218506 seconds
# Printed stage4_0000264.png in 14.113181114196777 seconds
# Printed stage4_0000265.png in 12.022581100463867 seconds
# Printed stage4_0000266.png in 12.389606237411499 seconds
# Printed stage4_0000267.png in 12.026162147521973 seconds
# Printed stage4_0000268.png in 13.754569053649902 seconds
# Printed stage4_0000269.png in 13.813652038574219 seconds
# Printed stage4_0000270.png in 11.645995855331421 seconds
# Printed stage4_0000271.png in 13.906967163085938 seconds
# Printed stage4_0000272.png in 12.154613018035889 seconds
# Printed stage4_0000273.png in 12.00413203239441 seconds
# Printed stage4_0000274.png in 11.649022102355957 seconds
# Printed stage4_0000275.png in 13.86051082611084 seconds
# Printed stage4_0000276.png in 14.298219919204712 seconds
# Printed stage4_0000277.png in 12.48418402671814 seconds
# Printed stage4_0000278.png in 11.668582916259766 seconds
# Printed stage4_0000279.png in 15.892393827438354 seconds
# Printed stage4_0000280.png in 12.743168830871582 seconds
# Printed stage4_0000281.png in 13.854992151260376 seconds
# Printed stage4_0000282.png in 14.68242883682251 seconds
# Printed stage4_0000283.png in 11.359233856201172 seconds
# Printed stage4_0000284.png in 11.451560258865356 seconds
# Printed stage4_0000285.png in 11.68247127532959 seconds
# Printed stage4_0000286.png in 13.514196872711182 seconds
# Printed stage4_0000287.png in 12.671751976013184 seconds
# Printed stage4_0000288.png in 11.832000970840454 seconds
# Printed stage4_0000289.png in 11.50112509727478 seconds
# Printed stage4_0000290.png in 14.254842042922974 seconds
# Printed stage4_0000291.png in 12.423612833023071 seconds
# Printed stage4_0000292.png in 11.98430585861206 seconds
# Printed stage4_0000293.png in 11.713435888290405 seconds
# Printed stage4_0000294.png in 14.149074077606201 seconds
# Printed stage4_0000295.png in 12.120921850204468 seconds
# Printed stage4_0000296.png in 11.92739200592041 seconds
# Printed stage4_0000297.png in 14.362190246582031 seconds
# Printed stage4_0000298.png in 12.182931184768677 seconds
# Printed stage4_0000299.png in 11.338594675064087 seconds
