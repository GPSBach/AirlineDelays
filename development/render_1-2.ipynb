# %%
import os
import conda

conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

from mpl_toolkits.basemap import Basemap

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pygrib
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
import time

def print_time(t0):
    t1 = time.time()
    return t1-t0

# %%
# starting and ending viewazimuths
azim_start = 270
azim_end = 270

# starting and ending view elevations
elev_start = 90
elev_end = 90

# starting and ending zooms
dist_start = 300
dist_end = 300

# starting and ending center latitude
lat_start = 43
lat_end = 43

# starting and ending longitude
lon_start = -97
lon_end = -97

# starting and ending layer separation
delev_start = 0
delev_end = 0

# delta center degrees
# latitude window for center
# tradoff with dist
ddeg = 1

#save files setup
savepath = '../plots/map/movie/animation/'
filename = 'stage1_'


num_steps = 300

t0 = time.time()

variables = ['Total Cloud Cover']
colors = ['viridis']
ranges = [(0,100)]

for i in range(num_steps):
    delev = delev_start-i*((delev_start-delev_end)/(num_steps-1))
    hour = str(i-24*(i//24)).zfill(2)
    day = str(1+i//24).zfill(2)
    try:
        grbs = pygrib.open(f'../data/weather/august_full/rap_130_201808{day}_{hour}00_000.grb2')
    except:
        pass
    
    datas = []
    elev = np.arange(len(variables))*delev

    for variable in variables:
        grb = grbs.select(name=variable)[0]
        lats, lons = grb.latlons()
        datas.append(grb['values'])

    map = Basemap(llcrnrlon=-360,llcrnrlat=-90,urcrnrlon=360,urcrnrlat=90,)

    fig = plt.figure(figsize=[10,10],dpi=150)
    ax = Axes3D(fig)

    ax.add_collection3d(map.drawcoastlines(linewidth=0.25))
    ax.add_collection3d(map.drawcountries(linewidth=0.35))

    ax.set_axis_off()
    ax.azim = azim_start-i*((azim_start-azim_end)/(num_steps-1))
    ax.elev = elev_start-i*((elev_start-elev_end)/(num_steps-1))
    ax.dist = dist_start-i*((dist_start-dist_end)/(num_steps-1))
    
    center_lat = lat_start-i*((lat_start-lat_end)/(num_steps-1))
    center_lon = lon_start-i*((lon_start-lon_end)/(num_steps-1))


    for ix,data in enumerate(datas):
        # fourth dimention - colormap
        # create colormap according to x-value (can use any 50x50 array)
        color_dimension = data # change to desired fourth dimension
        minn, maxx = color_dimension.min(), color_dimension.max()
        norm = matplotlib.colors.Normalize(minn, maxx)
        m = plt.cm.ScalarMappable(norm=norm, cmap=colors[ix])
        m.set_array([])
        fcolors = m.to_rgba(color_dimension)

        ax.plot_surface(lons,lats,np.ones(lats.shape)*elev[ix]+delev/10,cstride=2,rstride=2,facecolors=fcolors, vmin=ranges[ix][0], vmax=ranges[ix][0], shade=False)

    ax.set_xlim3d(center_lon-ddeg,center_lon+ddeg)
    ax.set_ylim3d(center_lat-ddeg,center_lat+ddeg)
    if i < 10:
        fig.savefig(f'{savepath}{filename}0000{i}.png', dpi=fig.dpi)
    elif i >=10 and i < 100:
        fig.savefig(f'{savepath}{filename}000{i}.png', dpi=fig.dpi)
    elif i >=100 and i < 1000:
        fig.savefig(f'{savepath}{filename}00{i}.png', dpi=fig.dpi)
    elif i > 1000:
        fig.savefig(f'{savepath}{filename}0{i}.png', dpi=fig.dpi)
    plt.close()
    print(f'Printed {filename}0000{i}.png in',print_time(t0),'seconds')
    t0 = time.time()
# Out:
# Printed stage1_00000.png in 13.020610094070435 seconds
# Printed stage1_00001.png in 14.549098014831543 seconds
# Printed stage1_00002.png in 17.45571208000183 seconds
# Printed stage1_00003.png in 17.459216117858887 seconds
# Printed stage1_00004.png in 22.920801877975464 seconds
# Printed stage1_00005.png in 19.725939989089966 seconds
# Printed stage1_00006.png in 20.366827964782715 seconds
# Printed stage1_00007.png in 29.847126960754395 seconds
# Printed stage1_00008.png in 22.129930019378662 seconds
# Printed stage1_00009.png in 24.396785974502563 seconds
# Printed stage1_000010.png in 27.955427169799805 seconds
# Printed stage1_000011.png in 24.330101013183594 seconds
# Printed stage1_000012.png in 18.884626865386963 seconds
# Printed stage1_000013.png in 21.49288511276245 seconds
# Printed stage1_000014.png in 20.922493934631348 seconds
# Printed stage1_000015.png in 22.33164691925049 seconds
# Printed stage1_000016.png in 19.436076879501343 seconds
# Printed stage1_000017.png in 23.42153310775757 seconds
# Printed stage1_000018.png in 30.033854961395264 seconds
# Printed stage1_000019.png in 34.27860140800476 seconds
# Printed stage1_000020.png in 33.16085886955261 seconds
# Printed stage1_000021.png in 29.479098081588745 seconds
# Printed stage1_000022.png in 30.540862798690796 seconds
# Printed stage1_000023.png in 36.95287799835205 seconds
# Printed stage1_000024.png in 23.98110008239746 seconds
# Printed stage1_000025.png in 22.571653842926025 seconds
# Printed stage1_000026.png in 29.84504795074463 seconds
# Printed stage1_000027.png in 45.95889091491699 seconds
# Printed stage1_000028.png in 21.88067078590393 seconds
# Printed stage1_000029.png in 22.026942014694214 seconds
# Printed stage1_000030.png in 33.65049600601196 seconds
# Printed stage1_000031.png in 22.370409965515137 seconds
# Printed stage1_000032.png in 28.498249053955078 seconds
# Printed stage1_000033.png in 33.49243116378784 seconds
# Printed stage1_000034.png in 128.37495708465576 seconds
# Printed stage1_000035.png in 29.972553968429565 seconds
# Printed stage1_000036.png in 41.67014408111572 seconds
# Printed stage1_000037.png in 25.44199800491333 seconds
# Printed stage1_000038.png in 22.570048093795776 seconds
# Printed stage1_000039.png in 32.66971802711487 seconds
# Printed stage1_000040.png in 31.908914804458618 seconds
# Printed stage1_000041.png in 29.50528311729431 seconds
# Printed stage1_000042.png in 23.61690592765808 seconds
# Printed stage1_000043.png in 40.740729093551636 seconds
# Printed stage1_000044.png in 49.72073984146118 seconds
# Printed stage1_000045.png in 45.797852993011475 seconds
# Printed stage1_000046.png in 39.00976586341858 seconds
# Printed stage1_000047.png in 36.709198236465454 seconds
# Printed stage1_000048.png in 34.657968044281006 seconds
# Printed stage1_000049.png in 50.69330191612244 seconds
# Printed stage1_000050.png in 39.11807608604431 seconds
# Printed stage1_000051.png in 46.269919872283936 seconds
# Printed stage1_000052.png in 60.128506898880005 seconds
# Printed stage1_000053.png in 57.37073588371277 seconds
# Printed stage1_000054.png in 42.36375403404236 seconds
# Printed stage1_000055.png in 48.716898918151855 seconds
# Printed stage1_000056.png in 49.521695375442505 seconds
# Printed stage1_000057.png in 38.588130950927734 seconds
# Printed stage1_000058.png in 47.265928745269775 seconds
# Printed stage1_000059.png in 46.867228984832764 seconds
# Printed stage1_000060.png in 48.406272172927856 seconds
# Printed stage1_000061.png in 31.496876001358032 seconds
# Printed stage1_000062.png in 41.63722109794617 seconds
# Printed stage1_000063.png in 28.912405014038086 seconds
# Printed stage1_000064.png in 40.67890787124634 seconds
# Printed stage1_000065.png in 48.09829497337341 seconds
# Printed stage1_000066.png in 43.22555899620056 seconds
# Printed stage1_000067.png in 38.6872398853302 seconds
# Printed stage1_000068.png in 32.516921281814575 seconds
# Printed stage1_000069.png in 27.0365731716156 seconds
# Printed stage1_000070.png in 56.25209188461304 seconds
# Printed stage1_000071.png in 63.90289521217346 seconds
# Printed stage1_000072.png in 43.47654128074646 seconds
# Printed stage1_000073.png in 44.62722086906433 seconds
# Printed stage1_000074.png in 50.10623097419739 seconds
# Printed stage1_000075.png in 43.19853901863098 seconds
# Printed stage1_000076.png in 58.71772313117981 seconds
# Printed stage1_000077.png in 42.71526312828064 seconds
# Printed stage1_000078.png in 35.76146602630615 seconds
# Printed stage1_000079.png in 41.5565288066864 seconds
# Printed stage1_000080.png in 38.149351835250854 seconds
# Printed stage1_000081.png in 58.89954686164856 seconds
# Printed stage1_000082.png in 36.840426206588745 seconds
# Printed stage1_000083.png in 33.185387134552 seconds
# Printed stage1_000084.png in 40.57449197769165 seconds
# Printed stage1_000085.png in 46.144675970077515 seconds
# Printed stage1_000086.png in 36.454508781433105 seconds
# Printed stage1_000087.png in 34.873769998550415 seconds
# Printed stage1_000088.png in 42.55925393104553 seconds
# Printed stage1_000089.png in 38.995903968811035 seconds
# Printed stage1_000090.png in 44.44711780548096 seconds
# Printed stage1_000091.png in 37.768911838531494 seconds
# Printed stage1_000092.png in 31.460607051849365 seconds
# Printed stage1_000093.png in 44.72028613090515 seconds
# Printed stage1_000094.png in 34.20649290084839 seconds
# Printed stage1_000095.png in 56.17935371398926 seconds
# Printed stage1_000096.png in 51.43303084373474 seconds
# Printed stage1_000097.png in 42.72744393348694 seconds
# Printed stage1_000098.png in 43.424665212631226 seconds
# Printed stage1_000099.png in 36.75341010093689 seconds
# Printed stage1_0000100.png in 27.655974864959717 seconds
# Printed stage1_0000101.png in 48.12881898880005 seconds
# Printed stage1_0000102.png in 57.98144483566284 seconds
# Printed stage1_0000103.png in 43.16841411590576 seconds
# Printed stage1_0000104.png in 46.252015113830566 seconds
# Printed stage1_0000105.png in 50.803640842437744 seconds
# Printed stage1_0000106.png in 41.05382823944092 seconds
# Printed stage1_0000107.png in 40.63230490684509 seconds
# Printed stage1_0000108.png in 36.011022090911865 seconds
# Printed stage1_0000109.png in 35.6707181930542 seconds
# Printed stage1_0000110.png in 42.95410919189453 seconds
# Printed stage1_0000111.png in 34.68069887161255 seconds
# Printed stage1_0000112.png in 51.78894519805908 seconds
# Printed stage1_0000113.png in 32.46163892745972 seconds
# Printed stage1_0000114.png in 23.464230060577393 seconds
# Printed stage1_0000115.png in 44.5255663394928 seconds
# Printed stage1_0000116.png in 37.98528599739075 seconds
# Printed stage1_0000117.png in 60.23691010475159 seconds
# Printed stage1_0000118.png in 46.77037501335144 seconds
# Printed stage1_0000119.png in 57.82715582847595 seconds
# Printed stage1_0000120.png in 46.66480493545532 seconds
# Printed stage1_0000121.png in 54.61647391319275 seconds
# Printed stage1_0000122.png in 40.31488800048828 seconds
# Printed stage1_0000123.png in 44.8159019947052 seconds
# Printed stage1_0000124.png in 20.8072772026062 seconds
# Printed stage1_0000125.png in 51.3116500377655 seconds
# Printed stage1_0000126.png in 41.602155923843384 seconds
# Printed stage1_0000127.png in 38.09827995300293 seconds
# Printed stage1_0000128.png in 55.10442399978638 seconds
# Printed stage1_0000129.png in 23.324212074279785 seconds
# Printed stage1_0000130.png in 28.53555703163147 seconds
# Printed stage1_0000131.png in 28.125128984451294 seconds
# Printed stage1_0000132.png in 23.194926977157593 seconds
# Printed stage1_0000133.png in 28.320507049560547 seconds
# Printed stage1_0000134.png in 44.13662886619568 seconds
# Printed stage1_0000135.png in 59.497567892074585 seconds
# Printed stage1_0000136.png in 35.794652223587036 seconds
# Printed stage1_0000137.png in 31.57024097442627 seconds
# Printed stage1_0000138.png in 43.47455620765686 seconds
# Printed stage1_0000139.png in 20.664262294769287 seconds
# Printed stage1_0000140.png in 50.857866048812866 seconds
# Printed stage1_0000141.png in 27.335330724716187 seconds
# Printed stage1_0000142.png in 51.148170709609985 seconds
# Printed stage1_0000143.png in 43.96940088272095 seconds
# Printed stage1_0000144.png in 37.28340005874634 seconds
# Printed stage1_0000145.png in 28.466870069503784 seconds
# Printed stage1_0000146.png in 22.599929094314575 seconds
# Printed stage1_0000147.png in 48.107715129852295 seconds
# Printed stage1_0000148.png in 34.246320962905884 seconds
# Printed stage1_0000149.png in 40.657613039016724 seconds
# Printed stage1_0000150.png in 26.347156047821045 seconds
# Printed stage1_0000151.png in 46.084654092788696 seconds
# Printed stage1_0000152.png in 43.081515073776245 seconds
# Printed stage1_0000153.png in 40.179482221603394 seconds
# Printed stage1_0000154.png in 81.30578994750977 seconds
# Printed stage1_0000155.png in 25.112439155578613 seconds
# Printed stage1_0000156.png in 40.64252591133118 seconds
# Printed stage1_0000157.png in 47.41423416137695 seconds
# Printed stage1_0000158.png in 46.318110942840576 seconds
# Printed stage1_0000267.png in 54.13995027542114 seconds
# Printed stage1_0000268.png in 67.18970227241516 seconds
# Printed stage1_0000269.png in 69.22679281234741 seconds
# Printed stage1_0000270.png in 43.989763259887695 seconds
# Printed stage1_0000271.png in 28.80189299583435 seconds
# Printed stage1_0000272.png in 82.28693914413452 seconds
# Printed stage1_0000273.png in 31.976222276687622 seconds
# Printed stage1_0000274.png in 52.62100410461426 seconds
# Printed stage1_0000275.png in 39.05947494506836 seconds
# Printed stage1_0000276.png in 56.26438808441162 seconds
# Printed stage1_0000277.png in 55.276461124420166 seconds
# Printed stage1_0000278.png in 39.360164165496826 seconds
# Printed stage1_0000279.png in 72.73997211456299 seconds
# Printed stage1_0000280.png in 31.5244357585907 seconds
# Printed stage1_0000281.png in 71.04748106002808 seconds
# Printed stage1_0000282.png in 47.623430252075195 seconds
# Printed stage1_0000283.png in 41.892600774765015 seconds
# Printed stage1_0000284.png in 29.75018286705017 seconds
# Printed stage1_0000285.png in 34.651647329330444 seconds
# Printed stage1_0000286.png in 89.51961588859558 seconds
# Printed stage1_0000287.png in 46.96248388290405 seconds
# Printed stage1_0000288.png in 55.703118085861206 seconds
# Printed stage1_0000289.png in 55.600791931152344 seconds
# Printed stage1_0000290.png in 34.31486511230469 seconds
# Printed stage1_0000291.png in 43.84362864494324 seconds
# Printed stage1_0000292.png in 83.01902222633362 seconds
# Printed stage1_0000293.png in 60.92793607711792 seconds
# Printed stage1_0000294.png in 81.71372199058533 seconds
# Printed stage1_0000295.png in 42.31541204452515 seconds
# Printed stage1_0000296.png in 50.78595495223999 seconds
# Printed stage1_0000297.png in 26.172767877578735 seconds
# Printed stage1_0000298.png in 64.70604109764099 seconds
# Printed stage1_0000299.png in 33.19683289527893 seconds

# %%
# starting and ending viewazimuths
azim_start = 270
azim_end = 200

# starting and ending view elevations
elev_start = 90
elev_end = 30

# starting and ending zooms
dist_start = 300
dist_end = 250

# starting and ending center latitude
lat_start = 43
lat_end = 50

# starting and ending longitude
lon_start = -97
lon_end = -80

# starting and ending layer separation
delev_start = 0
delev_end = 5

# delta center degrees
# latitude window for center
# tradoff with dist
ddeg = 1

#save files setup
savepath = '../plots/map/movie/animation/'
filename = 'stage2_'


num_steps = 300

t0 = time.time()

variables = ['Wind speed (gust)','Visibility','Maximum/Composite radar reflectivity','Total Cloud Cover']
colors = ['viridis','magma','jet','viridis']
ranges = [(0,10),(0,90000),(-10,50),(0,100)]

for i in range(num_steps):
    delev = delev_start-i*((delev_start-delev_end)/(num_steps-1))
    hour = str(i-24*(i//24)).zfill(2)
    day = str(1+i//24).zfill(2)
    try:
        grbs = pygrib.open(f'../data/weather/august_full/rap_130_201808{day}_{hour}00_000.grb2')
    except:
        pass
    
    datas = []
    elev = np.arange(len(variables))*delev

    for variable in variables:
        grb = grbs.select(name=variable)[0]
        lats, lons = grb.latlons()
        datas.append(grb['values'])

    map = Basemap(llcrnrlon=-360,llcrnrlat=-90,urcrnrlon=360,urcrnrlat=90,)

    fig = plt.figure(figsize=[10,10],dpi=150)
    ax = Axes3D(fig)

    ax.add_collection3d(map.drawcoastlines(linewidth=0.25))
    ax.add_collection3d(map.drawcountries(linewidth=0.35))

    ax.set_axis_off()
    ax.azim = azim_start-i*((azim_start-azim_end)/(num_steps-1))
    ax.elev = elev_start-i*((elev_start-elev_end)/(num_steps-1))
    ax.dist = dist_start-i*((dist_start-dist_end)/(num_steps-1))
    
    center_lat = lat_start-i*((lat_start-lat_end)/(num_steps-1))
    center_lon = lon_start-i*((lon_start-lon_end)/(num_steps-1))


    for ix,data in enumerate(datas):
        # fourth dimention - colormap
        # create colormap according to x-value (can use any 50x50 array)
        color_dimension = data # change to desired fourth dimension
        minn, maxx = color_dimension.min(), color_dimension.max()
        norm = matplotlib.colors.Normalize(minn, maxx)
        m = plt.cm.ScalarMappable(norm=norm, cmap=colors[ix])
        m.set_array([])
        fcolors = m.to_rgba(color_dimension)

        ax.plot_surface(lons,lats,np.ones(lats.shape)*elev[ix]+delev/10,cstride=2,rstride=2,facecolors=fcolors, vmin=ranges[ix][0], vmax=ranges[ix][0], shade=False)

    ax.set_xlim3d(center_lon-ddeg,center_lon+ddeg)
    ax.set_ylim3d(center_lat-ddeg,center_lat+ddeg)
    if i < 10:
        fig.savefig(f'{savepath}{filename}0000{i}.png', dpi=fig.dpi)
    elif i >=10 and i < 100:
        fig.savefig(f'{savepath}{filename}000{i}.png', dpi=fig.dpi)
    elif i >=100 and i < 1000:
        fig.savefig(f'{savepath}{filename}00{i}.png', dpi=fig.dpi)
    elif i > 1000:
        fig.savefig(f'{savepath}{filename}0{i}.png', dpi=fig.dpi)
    plt.close()
    print(f'Printed {filename}0000{i}.png in',print_time(t0),'seconds')
    t0 = time.time()
# Out:
# Printed stage2_00000.png in 236.69667601585388 seconds
# Printed stage2_00001.png in 73.2141592502594 seconds
# Printed stage2_00002.png in 99.31814694404602 seconds
# Printed stage2_00003.png in 105.12881278991699 seconds
# Printed stage2_00004.png in 152.5764319896698 seconds
# Printed stage2_00005.png in 269.67161417007446 seconds
# Printed stage2_00006.png in 488.69977712631226 seconds
# Printed stage2_00007.png in 478.41789293289185 seconds
# Printed stage2_00008.png in 293.5676968097687 seconds
# Printed stage2_00009.png in 299.2070951461792 seconds
# Printed stage2_000010.png in 232.45988082885742 seconds
# Printed stage2_000011.png in 192.97123789787292 seconds
# Printed stage2_000012.png in 149.26190209388733 seconds
# Printed stage2_000013.png in 130.26984405517578 seconds
# Printed stage2_000014.png in 140.39352822303772 seconds
# Printed stage2_000015.png in 198.9320478439331 seconds
# Printed stage2_000016.png in 143.20876097679138 seconds
# Printed stage2_000017.png in 120.50683307647705 seconds
# Printed stage2_000018.png in 93.59543514251709 seconds
# Printed stage2_000019.png in 165.58696913719177 seconds
