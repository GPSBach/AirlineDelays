# %%
import os
import conda

conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

from mpl_toolkits.basemap import Basemap

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pygrib
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
import time

def print_time(t0):
    t1 = time.time()
    return t1-t0

# %%
# starting and ending viewazimuths
azim_start = 200
azim_end = 200

# starting and ending view elevations
elev_start = 30
elev_end = 30

# starting and ending zooms
dist_start = 250
dist_end = 250

# starting and ending center latitude
lat_start = 50
lat_end = 50

# starting and ending longitude
lon_start = -80
lon_end = -80

# starting and ending layer separation
delev_start = 5
delev_end = 5

# delta center degrees
# latitude window for center
# tradoff with dist
ddeg = 1

#save files setup
savepath = '../plots/map/movie/animation/'
filename = 'stage3_'


num_steps = 300

t0 = time.time()

variables = ['Wind speed (gust)','Visibility','Maximum/Composite radar reflectivity','Total Cloud Cover']
colors = ['viridis','magma','jet','viridis']
ranges = [(0,10),(0,90000),(-10,50),(0,100)]

for i in range(num_steps):
    delev = delev_start-i*((delev_start-delev_end)/(num_steps-1))
    hour = str(i-24*(i//24)).zfill(2)
    day = str(1+i//24).zfill(2)
    try:
        grbs = pygrib.open(f'../data/weather/august_full/rap_130_201808{day}_{hour}00_000.grb2')
    except:
        pass
    
    datas = []
    elev = np.arange(len(variables))*delev

    for variable in variables:
        grb = grbs.select(name=variable)[0]
        lats, lons = grb.latlons()
        datas.append(grb['values'])

    map = Basemap(llcrnrlon=-360,llcrnrlat=-90,urcrnrlon=360,urcrnrlat=90,)

    fig = plt.figure(figsize=[10,10],dpi=150)
    ax = Axes3D(fig)

    ax.add_collection3d(map.drawcoastlines(linewidth=0.25))
    ax.add_collection3d(map.drawcountries(linewidth=0.35))

    ax.set_axis_off()
    ax.azim = azim_start-i*((azim_start-azim_end)/(num_steps-1))
    ax.elev = elev_start-i*((elev_start-elev_end)/(num_steps-1))
    ax.dist = dist_start-i*((dist_start-dist_end)/(num_steps-1))
    
    center_lat = lat_start-i*((lat_start-lat_end)/(num_steps-1))
    center_lon = lon_start-i*((lon_start-lon_end)/(num_steps-1))


    for ix,data in enumerate(datas):
        # fourth dimention - colormap
        # create colormap according to x-value (can use any 50x50 array)
        color_dimension = data # change to desired fourth dimension
        minn, maxx = color_dimension.min(), color_dimension.max()
        norm = matplotlib.colors.Normalize(minn, maxx)
        m = plt.cm.ScalarMappable(norm=norm, cmap=colors[ix])
        m.set_array([])
        fcolors = m.to_rgba(color_dimension)

        ax.plot_surface(lons,lats,np.ones(lats.shape)*elev[ix]+delev/10,cstride=2,rstride=2,facecolors=fcolors, vmin=ranges[ix][0], vmax=ranges[ix][0], shade=False)

    ax.set_xlim3d(center_lon-ddeg,center_lon+ddeg)
    ax.set_ylim3d(center_lat-ddeg,center_lat+ddeg)
    if i < 10:
        fig.savefig(f'{savepath}{filename}0000{i}.png', dpi=fig.dpi)
    elif i >=10 and i < 100:
        fig.savefig(f'{savepath}{filename}000{i}.png', dpi=fig.dpi)
    elif i >=100 and i < 1000:
        fig.savefig(f'{savepath}{filename}00{i}.png', dpi=fig.dpi)
    elif i > 1000:
        fig.savefig(f'{savepath}{filename}0{i}.png', dpi=fig.dpi)
    plt.close()
    print(f'Printed {filename}0000{i}.png in',print_time(t0),'seconds')
    t0 = time.time()
# Out:
# Printed stage3_00000.png in 59.70365309715271 seconds
# Printed stage3_00001.png in 103.04041314125061 seconds
# Printed stage3_00002.png in 81.47586512565613 seconds
# Printed stage3_00003.png in 74.00545191764832 seconds
# Printed stage3_00004.png in 111.34184288978577 seconds
# Printed stage3_00005.png in 100.8813989162445 seconds
# Printed stage3_00006.png in 78.46761107444763 seconds
# Printed stage3_00007.png in 99.98943519592285 seconds
# Printed stage3_00008.png in 101.14379715919495 seconds
# Printed stage3_00009.png in 83.56022810935974 seconds
# Printed stage3_000010.png in 92.75222301483154 seconds
# Printed stage3_000011.png in 90.61309099197388 seconds
# Printed stage3_000012.png in 67.68668913841248 seconds
# Printed stage3_000013.png in 103.14128613471985 seconds
# Printed stage3_000014.png in 138.0760178565979 seconds
# Printed stage3_000015.png in 149.78348016738892 seconds
# Printed stage3_000016.png in 94.20041084289551 seconds
# Printed stage3_000017.png in 104.61259698867798 seconds
# Printed stage3_000018.png in 136.0765142440796 seconds
# Printed stage3_000019.png in 92.18186402320862 seconds
# Printed stage3_000020.png in 112.53591990470886 seconds
# Printed stage3_000021.png in 113.57595014572144 seconds
# Printed stage3_000022.png in 143.3542308807373 seconds
# Printed stage3_000023.png in 150.38094091415405 seconds
# Printed stage3_000024.png in 153.6159508228302 seconds
# Printed stage3_000025.png in 141.22415900230408 seconds
# Printed stage3_000026.png in 109.12128186225891 seconds
# Printed stage3_000027.png in 111.10595178604126 seconds
# Printed stage3_000028.png in 129.6203088760376 seconds
# Printed stage3_000029.png in 111.42096304893494 seconds
# Printed stage3_000030.png in 114.05864119529724 seconds
# Printed stage3_000031.png in 104.92579174041748 seconds
# Printed stage3_000032.png in 124.75862097740173 seconds
# Printed stage3_000033.png in 79.96638011932373 seconds
# Printed stage3_000034.png in 138.06375408172607 seconds
# Printed stage3_000035.png in 104.14776921272278 seconds
# Printed stage3_000036.png in 101.17698526382446 seconds
# Printed stage3_000037.png in 128.7732150554657 seconds
# Printed stage3_000038.png in 105.02219295501709 seconds
# Printed stage3_000039.png in 103.90746903419495 seconds
# Printed stage3_000040.png in 103.12618899345398 seconds
# Printed stage3_000041.png in 145.45644998550415 seconds
# Printed stage3_000042.png in 142.60774087905884 seconds
# Printed stage3_000043.png in 152.47193098068237 seconds
# Printed stage3_000044.png in 123.66897797584534 seconds
# Printed stage3_000045.png in 139.8350179195404 seconds
# Printed stage3_000046.png in 154.41467308998108 seconds
# Printed stage3_000047.png in 114.88155889511108 seconds
# Printed stage3_000048.png in 103.00933289527893 seconds
# Printed stage3_000049.png in 142.3779718875885 seconds
# Printed stage3_000050.png in 147.23870205879211 seconds
# Printed stage3_000051.png in 123.5499517917633 seconds
# Printed stage3_000052.png in 135.83439111709595 seconds
# Printed stage3_000053.png in 110.67123699188232 seconds
# Printed stage3_000054.png in 140.33793687820435 seconds
# Printed stage3_000055.png in 182.59449195861816 seconds
# Printed stage3_000056.png in 140.84629082679749 seconds
# Printed stage3_000057.png in 119.24162483215332 seconds
# Printed stage3_000058.png in 149.53981494903564 seconds
# Printed stage3_000059.png in 137.66139197349548 seconds
# Printed stage3_000060.png in 151.33362007141113 seconds
# Printed stage3_000061.png in 122.34344601631165 seconds
# Printed stage3_000062.png in 155.6737470626831 seconds
# Printed stage3_000063.png in 112.65553307533264 seconds
# Printed stage3_000064.png in 151.4115071296692 seconds
# Printed stage3_000065.png in 145.2969810962677 seconds
# Printed stage3_000066.png in 103.77536988258362 seconds
# Printed stage3_000067.png in 140.86265802383423 seconds
# Printed stage3_000068.png in 179.07822608947754 seconds
# Printed stage3_000069.png in 102.66029906272888 seconds
# Printed stage3_000070.png in 141.070219039917 seconds
# Printed stage3_000071.png in 163.50083470344543 seconds
# Printed stage3_000072.png in 120.37837791442871 seconds
# Printed stage3_000073.png in 132.80036211013794 seconds
# Printed stage3_000074.png in 88.6654441356659 seconds
# Printed stage3_000075.png in 174.918771982193 seconds
# Printed stage3_000076.png in 119.89437699317932 seconds
# Printed stage3_000077.png in 252.3577630519867 seconds
# Printed stage3_000078.png in 115.70200181007385 seconds
# Printed stage3_000079.png in 124.85971593856812 seconds
# Printed stage3_000080.png in 139.23034405708313 seconds
# Printed stage3_000081.png in 106.08534026145935 seconds
# Printed stage3_000082.png in 166.25777411460876 seconds
# Printed stage3_000083.png in 106.66983604431152 seconds
# Printed stage3_000084.png in 142.9263780117035 seconds
# Printed stage3_000085.png in 122.62595009803772 seconds
# Printed stage3_000086.png in 248.3483772277832 seconds
# Printed stage3_000087.png in 127.48293399810791 seconds
# Printed stage3_000088.png in 258.21903109550476 seconds
# Printed stage3_000089.png in 138.73194813728333 seconds
# Printed stage3_000090.png in 136.60061526298523 seconds
# Printed stage3_000091.png in 177.93711924552917 seconds
# Printed stage3_000092.png in 126.09255075454712 seconds
# Printed stage3_000093.png in 192.94918513298035 seconds
# Printed stage3_000094.png in 135.3213450908661 seconds
# Printed stage3_000095.png in 164.6851818561554 seconds
# Printed stage3_000096.png in 128.0252070426941 seconds
# Printed stage3_000097.png in 182.46228098869324 seconds
# Printed stage3_000098.png in 98.43129420280457 seconds
# Printed stage3_000099.png in 83.22884726524353 seconds
# Printed stage3_0000100.png in 165.45742917060852 seconds
# Printed stage3_0000101.png in 110.07594013214111 seconds
# Printed stage3_0000102.png in 249.37815880775452 seconds
# Printed stage3_0000103.png in 119.85907196998596 seconds
# Printed stage3_0000104.png in 165.09516382217407 seconds
# Printed stage3_0000105.png in 101.3784749507904 seconds
# Printed stage3_0000106.png in 144.44247913360596 seconds
# Printed stage3_0000107.png in 299.88879227638245 seconds
# Printed stage3_0000108.png in 128.16325902938843 seconds
# Printed stage3_0000109.png in 174.0234019756317 seconds
# Printed stage3_0000110.png in 117.53160500526428 seconds
# Printed stage3_0000111.png in 148.51050806045532 seconds
# Printed stage3_0000112.png in 340.8896448612213 seconds
# Printed stage3_0000113.png in 101.68934607505798 seconds
# Printed stage3_0000114.png in 99.97687101364136 seconds
# Printed stage3_0000115.png in 141.9854371547699 seconds
# Printed stage3_0000116.png in 97.55063796043396 seconds
# Printed stage3_0000117.png in 193.8673117160797 seconds
# Printed stage3_0000118.png in 115.12670993804932 seconds
# Printed stage3_0000119.png in 78.66636800765991 seconds
# Printed stage3_0000120.png in 398.0544128417969 seconds
# Printed stage3_0000121.png in 104.02008700370789 seconds
# Printed stage3_0000122.png in 108.80409288406372 seconds
# Printed stage3_0000123.png in 340.7375910282135 seconds
# Printed stage3_0000124.png in 136.31166100502014 seconds
# Printed stage3_0000125.png in 109.30579280853271 seconds
# Printed stage3_0000126.png in 162.73087620735168 seconds
# Printed stage3_0000127.png in 143.79580903053284 seconds
# Printed stage3_0000128.png in 125.41443824768066 seconds
# Printed stage3_0000129.png in 168.21914672851562 seconds
# Printed stage3_0000130.png in 139.27384400367737 seconds
# Printed stage3_0000131.png in 124.13938283920288 seconds
# Printed stage3_0000132.png in 197.9482297897339 seconds
# Printed stage3_0000133.png in 88.82003402709961 seconds
# Printed stage3_0000134.png in 111.43486094474792 seconds
# Printed stage3_0000135.png in 175.36036205291748 seconds
# Printed stage3_0000136.png in 106.22359895706177 seconds
# Printed stage3_0000137.png in 112.88539218902588 seconds
# Printed stage3_0000138.png in 175.48072504997253 seconds
# Printed stage3_0000139.png in 118.08638072013855 seconds
# Printed stage3_0000140.png in 139.52769303321838 seconds
# Printed stage3_0000141.png in 115.56360507011414 seconds
# Printed stage3_0000142.png in 208.732816696167 seconds
# Printed stage3_0000143.png in 137.60319209098816 seconds
# Printed stage3_0000144.png in 128.74631595611572 seconds
# Printed stage3_0000145.png in 156.49779200553894 seconds
# Printed stage3_0000146.png in 109.34707880020142 seconds
# Printed stage3_0000147.png in 116.34038615226746 seconds
# Printed stage3_0000148.png in 177.6326150894165 seconds
# Printed stage3_0000149.png in 159.31461095809937 seconds
# Printed stage3_0000150.png in 100.48435521125793 seconds
# Printed stage3_0000151.png in 110.32156610488892 seconds
# Printed stage3_0000152.png in 191.85510396957397 seconds
# Printed stage3_0000153.png in 89.65712308883667 seconds
# Printed stage3_0000154.png in 141.43086791038513 seconds
# Printed stage3_0000155.png in 132.36223006248474 seconds
# Printed stage3_0000156.png in 191.28623795509338 seconds
# Printed stage3_0000157.png in 87.8798680305481 seconds
# Printed stage3_0000158.png in 94.98846673965454 seconds
# Printed stage3_0000159.png in 214.7852499485016 seconds
# Printed stage3_0000160.png in 131.0095419883728 seconds
# Printed stage3_0000161.png in 113.68393802642822 seconds
# Printed stage3_0000162.png in 127.45814776420593 seconds
# Printed stage3_0000163.png in 183.99347496032715 seconds
# Printed stage3_0000164.png in 163.56740880012512 seconds
# Printed stage3_0000165.png in 208.67720293998718 seconds
# Printed stage3_0000166.png in 102.90300273895264 seconds
# Printed stage3_0000167.png in 355.25019812583923 seconds
# Printed stage3_0000168.png in 154.90264129638672 seconds
# Printed stage3_0000169.png in 130.50390696525574 seconds
# Printed stage3_0000170.png in 161.29183077812195 seconds
# Printed stage3_0000171.png in 199.8617730140686 seconds
# Printed stage3_0000172.png in 92.22879385948181 seconds
# Printed stage3_0000173.png in 92.56908011436462 seconds
# Printed stage3_0000174.png in 116.86100506782532 seconds
# Printed stage3_0000175.png in 326.65531611442566 seconds
# Printed stage3_0000176.png in 120.64085006713867 seconds
# Printed stage3_0000177.png in 101.5747709274292 seconds
# Printed stage3_0000178.png in 154.37401866912842 seconds
# Printed stage3_0000179.png in 288.48089504241943 seconds
# Printed stage3_0000180.png in 124.60192275047302 seconds
# Printed stage3_0000181.png in 129.72976899147034 seconds
# Printed stage3_0000182.png in 102.30316305160522 seconds
# Printed stage3_0000183.png in 184.96065711975098 seconds
# Printed stage3_0000184.png in 119.55637502670288 seconds
# Printed stage3_0000185.png in 122.07989525794983 seconds
# Printed stage3_0000186.png in 148.8061170578003 seconds

# %%
# starting and ending viewazimuths
azim_start = 200
azim_end = 270

# starting and ending view elevations
elev_start = 30
elev_end = 90

# starting and ending zooms
dist_start = 250
dist_end = 230

# starting and ending center latitude
lat_start = 50
lat_end = 38.5

# starting and ending longitude
lon_start = -80
lon_end = -97.5

# starting and ending layer separation
delev_start = 5
delev_end = 0

# delta center degrees
# latitude window for center
# tradoff with dist
ddeg = 1

#save files setup
savepath = '../plots/map/movie/animation/'
filename = 'stage4_'


num_steps = 300

t0 = time.time()

variables = ['Wind speed (gust)','Visibility','Maximum/Composite radar reflectivity','Total Cloud Cover']
colors = ['viridis','magma','jet','viridis']
ranges = [(0,10),(0,90000),(-10,50),(0,100)]

for i in range(num_steps):
    delev = delev_start-i*((delev_start-delev_end)/(num_steps-1))
    hour = str(i-24*(i//24)).zfill(2)
    day = str(1+i//24).zfill(2)
    try:
        grbs = pygrib.open(f'../data/weather/august_full/rap_130_201808{day}_{hour}00_000.grb2')
    except:
        pass
    
    datas = []
    elev = np.arange(len(variables))*delev

    for variable in variables:
        grb = grbs.select(name=variable)[0]
        lats, lons = grb.latlons()
        datas.append(grb['values'])

    map = Basemap(llcrnrlon=-360,llcrnrlat=-90,urcrnrlon=360,urcrnrlat=90,)

    fig = plt.figure(figsize=[10,10],dpi=150)
    ax = Axes3D(fig)

    ax.add_collection3d(map.drawcoastlines(linewidth=0.25))
    ax.add_collection3d(map.drawcountries(linewidth=0.35))

    ax.set_axis_off()
    ax.azim = azim_start-i*((azim_start-azim_end)/(num_steps-1))
    ax.elev = elev_start-i*((elev_start-elev_end)/(num_steps-1))
    ax.dist = dist_start-i*((dist_start-dist_end)/(num_steps-1))
    
    center_lat = lat_start-i*((lat_start-lat_end)/(num_steps-1))
    center_lon = lon_start-i*((lon_start-lon_end)/(num_steps-1))


    for ix,data in enumerate(datas):
        # fourth dimention - colormap
        # create colormap according to x-value (can use any 50x50 array)
        color_dimension = data # change to desired fourth dimension
        minn, maxx = color_dimension.min(), color_dimension.max()
        norm = matplotlib.colors.Normalize(minn, maxx)
        m = plt.cm.ScalarMappable(norm=norm, cmap=colors[ix])
        m.set_array([])
        fcolors = m.to_rgba(color_dimension)

        ax.plot_surface(lons,lats,np.ones(lats.shape)*elev[ix]+delev/10,cstride=2,rstride=2,facecolors=fcolors, vmin=ranges[ix][0], vmax=ranges[ix][0], shade=False)

    ax.set_xlim3d(center_lon-ddeg,center_lon+ddeg)
    ax.set_ylim3d(center_lat-ddeg,center_lat+ddeg)
    if i < 10:
        fig.savefig(f'{savepath}{filename}0000{i}.png', dpi=fig.dpi)
    elif i >=10 and i < 100:
        fig.savefig(f'{savepath}{filename}000{i}.png', dpi=fig.dpi)
    elif i >=100 and i < 1000:
        fig.savefig(f'{savepath}{filename}00{i}.png', dpi=fig.dpi)
    elif i > 1000:
        fig.savefig(f'{savepath}{filename}0{i}.png', dpi=fig.dpi)
    plt.close()
    print(f'Printed {filename}0000{i}.png in',print_time(t0),'seconds')
    t0 = time.time()
