# %%
import os
import conda

conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

from mpl_toolkits.basemap import Basemap

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pygrib
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
import time

def print_time(t0):
    t1 = time.time()
    return t1-t0

# %%
# starting and ending viewazimuths
azim_start = 270
azim_end = 270

# starting and ending view elevations
elev_start = 90
elev_end = 90

# starting and ending zooms
dist_start = 230
dist_end = 230#100

#airport coordinates
lat_DEN = 39.7392
lon_DEN = -104.9903
lat_MIA = 25.7617
lon_MIA = -80.1918

# starting and ending center latitude
lat_start = 38.5
lat_end = 38.5#(lat_DEN+lat_MIA)/2

# starting and ending longitude
lon_start = -97.5
lon_end = -97.5#(lon_DEN+lon_MIA)/2

# starting and ending layer separation
delev_start = 0
delev_end = 0

#latitude windows
degree_window_start = 5
degree_window_end = 5

# delta center degrees
# latitude window for center
# tradoff with dist
ddeg = 1

#save files setup
savepath = '../plots/map/movie/animation/'
filename = 'stage7_'


num_steps = 150

t0 = time.time()

variables = ['Total Cloud Cover']
colors = ['viridis']
ranges = [(0,100)]

for i in range(num_steps):
    delev = delev_start-i*((delev_start-delev_end)/(num_steps-1))
    degree_window = degree_window_start-i*((degree_window_start-degree_window_end)/(num_steps-1))
    hour = str(i-24*(i//24)).zfill(2)
    day = str(1+i//24).zfill(2)
    try:
        grbs = pygrib.open(f'../data/weather/august_full/rap_130_201808{day}_{hour}00_000.grb2')
    except:
        pass
    
    datas = []
    elev = np.arange(len(variables))*delev

    for variable in variables:
        grb = grbs.select(name=variable)[0]
        lats, lons = grb.latlons()
        datas.append(grb['values'])

    map = Basemap(llcrnrlon=-360,llcrnrlat=-90,urcrnrlon=360,urcrnrlat=90,)

    fig = plt.figure(figsize=[10,10],dpi=150)
    ax = Axes3D(fig)

    ax.add_collection3d(map.drawcoastlines(linewidth=0.25))
    ax.add_collection3d(map.drawcountries(linewidth=0.35))

    ax.set_axis_off()
    ax.azim = azim_start-i*((azim_start-azim_end)/(num_steps-1))
    ax.elev = elev_start-i*((elev_start-elev_end)/(num_steps-1))
    ax.dist = dist_start-i*((dist_start-dist_end)/(num_steps-1))
    
    center_lat = lat_start-i*((lat_start-lat_end)/(num_steps-1))
    center_lon = lon_start-i*((lon_start-lon_end)/(num_steps-1))


    for ix,data in enumerate(datas):
        # fourth dimention - colormap
        # create colormap according to x-value (can use any 50x50 array)
        color_dimension = data # change to desired fourth dimension
        minn, maxx = color_dimension.min(), color_dimension.max()
        norm = matplotlib.colors.Normalize(minn, maxx)
        m = plt.cm.ScalarMappable(norm=norm, cmap=colors[ix])
        m.set_array([])
        fcolors = m.to_rgba(color_dimension)
        Z_DEN = np.ones(lats.shape)*elev[ix]+delev/10
        Z_MIA = np.ones(lats.shape)*elev[ix]+delev/10
        mask_DEN = np.ma.masked_where((np.sqrt((lats-lat_DEN)**2 + (lons-lon_DEN)**2) > degree_window), Z_DEN)
        mask_MIA = np.ma.masked_where((np.sqrt((lats-lat_MIA)**2 + (lons-lon_MIA)**2) > degree_window), Z_MIA)
        Z_DEN[np.where(np.ma.getmask(mask_DEN)==True)] = np.nan # or np.where(np.ma.getmask(mask2)==True)] = np.nan
        Z_MIA[np.where(np.ma.getmask(mask_MIA)==True)] = np.nan
        
        ax.plot_surface(lons,lats,Z_DEN,cstride=5,rstride=5,facecolors=fcolors, vmin=ranges[ix][0], vmax=ranges[ix][0], shade=False)
        ax.plot_surface(lons,lats,Z_MIA,cstride=5,rstride=5,facecolors=fcolors, vmin=ranges[ix][0], vmax=ranges[ix][0], shade=False)
        ax.scatter(lon_DEN, lat_DEN, 0,color='r',marker='o',linewidth=10)

    ax.set_xlim3d(center_lon-ddeg,center_lon+ddeg)
    ax.set_ylim3d(center_lat-ddeg,center_lat+ddeg)
    if i < 10:
        fig.savefig(f'{savepath}{filename}0000{i}.png', dpi=fig.dpi)
    elif i >=10 and i < 100:
        fig.savefig(f'{savepath}{filename}000{i}.png', dpi=fig.dpi)
    elif i >=100 and i < 1000:
        fig.savefig(f'{savepath}{filename}00{i}.png', dpi=fig.dpi)
    elif i > 1000:
        fig.savefig(f'{savepath}{filename}0{i}.png', dpi=fig.dpi)
    plt.close()
    print(f'Printed {filename}0000{i}.png in',print_time(t0),'seconds')
    t0 = time.time()
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# Printed stage7_00000.png in 6.981856107711792 seconds
# Printed stage7_00001.png in 7.288967132568359 seconds
# Printed stage7_00002.png in 7.384269714355469 seconds
# Printed stage7_00003.png in 7.142391920089722 seconds
# Printed stage7_00004.png in 8.042937278747559 seconds
# Printed stage7_00005.png in 7.732732772827148 seconds
# Printed stage7_00006.png in 7.778301954269409 seconds
# Printed stage7_00007.png in 7.4019811153411865 seconds
# Printed stage7_00008.png in 6.901906967163086 seconds
# Printed stage7_00009.png in 7.117324113845825 seconds
# Printed stage7_000010.png in 7.494078874588013 seconds
# Printed stage7_000011.png in 7.356518030166626 seconds
# Printed stage7_000012.png in 7.249267816543579 seconds
# Printed stage7_000013.png in 6.86188006401062 seconds
# Printed stage7_000014.png in 7.519423007965088 seconds
# Printed stage7_000015.png in 7.66187596321106 seconds
# Printed stage7_000016.png in 7.7635579109191895 seconds
# Printed stage7_000017.png in 7.677397012710571 seconds
# Printed stage7_000018.png in 7.515951871871948 seconds
# Printed stage7_000019.png in 6.896448135375977 seconds
# Printed stage7_000020.png in 6.947055101394653 seconds
# Printed stage7_000021.png in 6.824367046356201 seconds
# Printed stage7_000022.png in 6.972208261489868 seconds
# Printed stage7_000023.png in 6.553544759750366 seconds
# Printed stage7_000024.png in 6.79043984413147 seconds
# Printed stage7_000025.png in 7.161535024642944 seconds
# Printed stage7_000026.png in 6.984571218490601 seconds
# Printed stage7_000027.png in 6.799703121185303 seconds
# Printed stage7_000028.png in 7.01087212562561 seconds
# Printed stage7_000029.png in 7.623649835586548 seconds
# Printed stage7_000030.png in 6.962070941925049 seconds
# Printed stage7_000031.png in 6.994939804077148 seconds
# Printed stage7_000032.png in 7.327951192855835 seconds
# Printed stage7_000033.png in 7.763320684432983 seconds
# Printed stage7_000034.png in 7.596780061721802 seconds
# Printed stage7_000035.png in 7.348121166229248 seconds
# Printed stage7_000036.png in 7.380555868148804 seconds
# Printed stage7_000037.png in 7.266350269317627 seconds
# Printed stage7_000038.png in 7.692633867263794 seconds
# Printed stage7_000098.png in 7.862385988235474 seconds
# Printed stage7_000099.png in 8.196358680725098 seconds
# Printed stage7_0000100.png in 8.311860084533691 seconds
# Printed stage7_0000101.png in 8.29564905166626 seconds
# Printed stage7_0000102.png in 7.654344081878662 seconds
# Printed stage7_0000103.png in 7.760608911514282 seconds
# Printed stage7_0000104.png in 7.2081298828125 seconds
# Printed stage7_0000105.png in 7.9793689250946045 seconds
# Printed stage7_0000106.png in 7.920806884765625 seconds
# Printed stage7_0000107.png in 7.1894447803497314 seconds
# Printed stage7_0000108.png in 7.3549089431762695 seconds
# Printed stage7_0000109.png in 7.253899097442627 seconds
# Printed stage7_0000110.png in 7.047352075576782 seconds
# Printed stage7_0000111.png in 7.581374883651733 seconds
# Printed stage7_0000112.png in 7.718390941619873 seconds
# Printed stage7_0000113.png in 8.308622121810913 seconds
# Printed stage7_0000114.png in 7.017233848571777 seconds
# Printed stage7_0000115.png in 7.3218419551849365 seconds
# Printed stage7_0000116.png in 8.09834337234497 seconds
# Printed stage7_0000117.png in 6.937593221664429 seconds
# Printed stage7_0000118.png in 7.494557857513428 seconds
# Printed stage7_0000119.png in 6.611685276031494 seconds
# Printed stage7_0000120.png in 8.452973127365112 seconds
# Printed stage7_0000121.png in 7.914292812347412 seconds
# Printed stage7_0000122.png in 8.262176036834717 seconds
# Printed stage7_0000123.png in 10.09160304069519 seconds
# Printed stage7_0000124.png in 8.307358980178833 seconds
# Printed stage7_0000125.png in 9.745260953903198 seconds
# Printed stage7_0000126.png in 8.953618288040161 seconds
# Printed stage7_0000127.png in 11.538414001464844 seconds
# Printed stage7_0000128.png in 10.807845115661621 seconds
# Printed stage7_0000129.png in 10.347154140472412 seconds
# Printed stage7_0000130.png in 8.6068856716156 seconds
# Printed stage7_0000131.png in 9.473563194274902 seconds
# Printed stage7_0000132.png in 8.176284790039062 seconds
# Printed stage7_0000133.png in 8.489626169204712 seconds
# Printed stage7_0000134.png in 7.5234761238098145 seconds
# Printed stage7_0000135.png in 8.777298927307129 seconds
# Printed stage7_0000136.png in 9.093332052230835 seconds
# Printed stage7_0000137.png in 8.931542158126831 seconds
# Printed stage7_0000138.png in 8.955583095550537 seconds
# Printed stage7_0000139.png in 9.428925037384033 seconds
# Printed stage7_0000140.png in 8.354228258132935 seconds
# Printed stage7_0000141.png in 9.012168169021606 seconds
# Printed stage7_0000142.png in 8.515742063522339 seconds
# Printed stage7_0000143.png in 8.557638168334961 seconds
# Printed stage7_0000144.png in 8.845206022262573 seconds
# Printed stage7_0000145.png in 10.809536933898926 seconds
# Printed stage7_0000146.png in 8.81772494316101 seconds
# Printed stage7_0000147.png in 9.23168396949768 seconds
# Printed stage7_0000148.png in 8.221104860305786 seconds
# Printed stage7_0000149.png in 6.874011993408203 seconds

# %%
plt.imshow(mask)

# %%
mask = np.ma.masked_where((np.absolute(lats-lat_MIA)<lat_window,Z))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-8a5c04d3650d> in <module>()
# ----> 1 mask = np.ma.masked_where((np.absolute(lats-lat_MIA)<lat_window,Z))
#
# TypeError: masked_where() missing 1 required positional argument: 'a'
