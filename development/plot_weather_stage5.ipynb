# %%
import os
import conda

conda_file_dir = conda.__file__
conda_dir = conda_file_dir.split('lib')[0]
proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
os.environ["PROJ_LIB"] = proj_lib

from mpl_toolkits.basemap import Basemap

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pygrib
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
import time

def print_time(t0):
    t1 = time.time()
    return t1-t0

# %%
# starting and ending viewazimuths
azim_start = 270
azim_end = 270

# starting and ending view elevations
elev_start = 90
elev_end = 90

# starting and ending zooms
dist_start = 230
dist_end = 230

# starting and ending center latitude
lat_start = 38.5
lat_end = 38.5

# starting and ending longitude
lon_start = -97.5
lon_end = -97.5

# starting and ending layer separation
delev_start = 0
delev_end = 0

# delta center degrees
# latitude window for center
# tradoff with dist
ddeg = 1

#save files setup
savepath = '../plots/map/movie/animation/'
filename = 'stage5_'


num_steps = 300

t0 = time.time()

variables = ['Total Cloud Cover']
colors = ['viridis']
ranges = [(0,100)]

for i in range(num_steps):
    delev = delev_start-i*((delev_start-delev_end)/(num_steps-1))
    hour = str(i-24*(i//24)).zfill(2)
    day = str(1+i//24).zfill(2)
    try:
        grbs = pygrib.open(f'../data/weather/august_full/rap_130_201808{day}_{hour}00_000.grb2')
    except:
        pass
    
    datas = []
    elev = np.arange(len(variables))*delev

    for variable in variables:
        grb = grbs.select(name=variable)[0]
        lats, lons = grb.latlons()
        datas.append(grb['values'])

    map = Basemap(llcrnrlon=-360,llcrnrlat=-90,urcrnrlon=360,urcrnrlat=90,)

    fig = plt.figure(figsize=[10,10],dpi=150)
    ax = Axes3D(fig)

    ax.add_collection3d(map.drawcoastlines(linewidth=0.25))
    ax.add_collection3d(map.drawcountries(linewidth=0.35))

    ax.set_axis_off()
    ax.azim = azim_start-i*((azim_start-azim_end)/(num_steps-1))
    ax.elev = elev_start-i*((elev_start-elev_end)/(num_steps-1))
    ax.dist = dist_start-i*((dist_start-dist_end)/(num_steps-1))
    
    center_lat = lat_start-i*((lat_start-lat_end)/(num_steps-1))
    center_lon = lon_start-i*((lon_start-lon_end)/(num_steps-1))


    for ix,data in enumerate(datas):
        # fourth dimention - colormap
        # create colormap according to x-value (can use any 50x50 array)
        color_dimension = data # change to desired fourth dimension
        minn, maxx = color_dimension.min(), color_dimension.max()
        norm = matplotlib.colors.Normalize(minn, maxx)
        m = plt.cm.ScalarMappable(norm=norm, cmap=colors[ix])
        m.set_array([])
        fcolors = m.to_rgba(color_dimension)

        ax.plot_surface(lons,lats,np.ones(lats.shape)*elev[ix]+delev/10,cstride=5,rstride=5,facecolors=fcolors, vmin=ranges[ix][0], vmax=ranges[ix][0], shade=False)

    ax.set_xlim3d(center_lon-ddeg,center_lon+ddeg)
    ax.set_ylim3d(center_lat-ddeg,center_lat+ddeg)
    if i < 10:
        fig.savefig(f'{savepath}{filename}0000{i}.png', dpi=fig.dpi)
    elif i >=10 and i < 100:
        fig.savefig(f'{savepath}{filename}000{i}.png', dpi=fig.dpi)
    elif i >=100 and i < 1000:
        fig.savefig(f'{savepath}{filename}00{i}.png', dpi=fig.dpi)
    elif i > 1000:
        fig.savefig(f'{savepath}{filename}0{i}.png', dpi=fig.dpi)
    plt.close()
    print(f'Printed {filename}0000{i}.png in',print_time(t0),'seconds')
    t0 = time.time()
# Out:
# Printed stage5_00000.png in 15.039880275726318 seconds
# Printed stage5_00001.png in 7.381520986557007 seconds
# Printed stage5_00002.png in 7.871593952178955 seconds
# Printed stage5_00003.png in 7.61188006401062 seconds
# Printed stage5_00004.png in 6.7567479610443115 seconds
# Printed stage5_00005.png in 6.458528995513916 seconds
# Printed stage5_00006.png in 6.3609490394592285 seconds
# Printed stage5_00007.png in 7.268065929412842 seconds
# Printed stage5_00008.png in 6.859618902206421 seconds
# Printed stage5_00009.png in 6.932477951049805 seconds
# Printed stage5_000010.png in 7.511664867401123 seconds
# Printed stage5_000011.png in 7.975476980209351 seconds
# Printed stage5_000012.png in 8.430405855178833 seconds
# Printed stage5_000013.png in 7.435280084609985 seconds
# Printed stage5_000014.png in 7.264759063720703 seconds
# Printed stage5_000015.png in 7.072877883911133 seconds
# Printed stage5_000016.png in 7.588289022445679 seconds
# Printed stage5_000017.png in 7.473560094833374 seconds
# Printed stage5_000018.png in 7.292527198791504 seconds
# Printed stage5_000019.png in 7.8408589363098145 seconds
# Printed stage5_000020.png in 7.99176287651062 seconds
# Printed stage5_000021.png in 6.812258005142212 seconds
# Printed stage5_000022.png in 7.99104380607605 seconds
# Printed stage5_000023.png in 7.980034112930298 seconds
# Printed stage5_000024.png in 7.225167989730835 seconds
# Printed stage5_000025.png in 7.8772292137146 seconds
# Printed stage5_000026.png in 8.031445980072021 seconds
# Printed stage5_000027.png in 7.343793153762817 seconds
# Printed stage5_000028.png in 7.765778064727783 seconds
# Printed stage5_000029.png in 7.118791341781616 seconds
# Printed stage5_000030.png in 7.4404520988464355 seconds
# Printed stage5_000031.png in 7.700724124908447 seconds
# Printed stage5_000032.png in 7.753642797470093 seconds
# Printed stage5_000033.png in 7.099898099899292 seconds
# Printed stage5_000034.png in 8.653779983520508 seconds
# Printed stage5_000035.png in 8.00800895690918 seconds
# Printed stage5_000036.png in 7.3555028438568115 seconds
# Printed stage5_000037.png in 6.891486167907715 seconds
# Printed stage5_000038.png in 7.864231824874878 seconds
# Printed stage5_000039.png in 9.044883012771606 seconds
# Printed stage5_000040.png in 8.333108901977539 seconds
# Printed stage5_000041.png in 7.428004026412964 seconds
# Printed stage5_000042.png in 7.4255781173706055 seconds
# Printed stage5_000043.png in 8.26137900352478 seconds
# Printed stage5_000044.png in 7.3459930419921875 seconds
# Printed stage5_000045.png in 7.1079699993133545 seconds
# Printed stage5_000046.png in 7.646055221557617 seconds
# Printed stage5_000047.png in 9.389134168624878 seconds
# Printed stage5_000048.png in 8.357809066772461 seconds
# Printed stage5_000049.png in 8.717684984207153 seconds
# Printed stage5_000050.png in 8.340532064437866 seconds
# Printed stage5_000051.png in 7.730746030807495 seconds
# Printed stage5_000052.png in 8.106065273284912 seconds
# Printed stage5_000053.png in 8.710957765579224 seconds
# Printed stage5_000054.png in 8.014106035232544 seconds
# Printed stage5_000055.png in 7.162841796875 seconds
# Printed stage5_000056.png in 6.768365144729614 seconds
# Printed stage5_000057.png in 7.237681865692139 seconds
# Printed stage5_000058.png in 7.064749002456665 seconds
# Printed stage5_000059.png in 7.917402029037476 seconds
# Printed stage5_000060.png in 8.921118974685669 seconds
# Printed stage5_000061.png in 7.888076066970825 seconds
# Printed stage5_000062.png in 7.615639686584473 seconds
# Printed stage5_000063.png in 5.911376953125 seconds
# Printed stage5_000064.png in 5.957564353942871 seconds
# Printed stage5_000065.png in 6.973395109176636 seconds
# Printed stage5_000066.png in 5.982313871383667 seconds
# Printed stage5_000067.png in 6.0865020751953125 seconds
# Printed stage5_000068.png in 6.02349591255188 seconds
# Printed stage5_000069.png in 6.784305095672607 seconds
# Printed stage5_000070.png in 6.518896102905273 seconds
# Printed stage5_000071.png in 5.6524338722229 seconds
# Printed stage5_000072.png in 6.152285099029541 seconds
# Printed stage5_000073.png in 6.937579154968262 seconds
# Printed stage5_000074.png in 6.132381916046143 seconds
# Printed stage5_000075.png in 5.89988374710083 seconds
# Printed stage5_000076.png in 5.713189125061035 seconds
# Printed stage5_000077.png in 5.420742034912109 seconds
# Printed stage5_000078.png in 5.280785083770752 seconds
# Printed stage5_000079.png in 6.254580974578857 seconds
# Printed stage5_000080.png in 5.223087787628174 seconds
# Printed stage5_000081.png in 5.68048882484436 seconds
# Printed stage5_000082.png in 5.194386005401611 seconds
# Printed stage5_000083.png in 4.99447774887085 seconds
# Printed stage5_000084.png in 5.302266836166382 seconds
# Printed stage5_000085.png in 5.20123291015625 seconds
# Printed stage5_000086.png in 5.963081121444702 seconds
# Printed stage5_000087.png in 5.334187030792236 seconds
# Printed stage5_000088.png in 4.923591136932373 seconds
# Printed stage5_000089.png in 5.17451810836792 seconds
# Printed stage5_000090.png in 6.063950061798096 seconds
# Printed stage5_000091.png in 5.128687143325806 seconds
# Printed stage5_000092.png in 5.303678274154663 seconds
# Printed stage5_000093.png in 5.1988160610198975 seconds
# Printed stage5_000094.png in 5.344030141830444 seconds
# Printed stage5_000095.png in 4.996464252471924 seconds
# Printed stage5_000096.png in 5.744474172592163 seconds
# Printed stage5_000097.png in 6.621963977813721 seconds
# Printed stage5_000098.png in 6.05497670173645 seconds
# Printed stage5_000099.png in 5.3304479122161865 seconds
# Printed stage5_0000100.png in 5.128996849060059 seconds
# Printed stage5_0000101.png in 5.040897846221924 seconds
# Printed stage5_0000102.png in 5.154980659484863 seconds
# Printed stage5_0000103.png in 4.7621190547943115 seconds
# Printed stage5_0000104.png in 5.477177858352661 seconds
# Printed stage5_0000105.png in 5.006493091583252 seconds
# Printed stage5_0000106.png in 4.9895548820495605 seconds
# Printed stage5_0000107.png in 5.2539660930633545 seconds
# Printed stage5_0000108.png in 4.886929988861084 seconds
# Printed stage5_0000109.png in 5.789736986160278 seconds
# Printed stage5_0000110.png in 5.100586175918579 seconds
# Printed stage5_0000111.png in 5.341104984283447 seconds
# Printed stage5_0000112.png in 5.0194220542907715 seconds
# Printed stage5_0000113.png in 5.490311145782471 seconds
# Printed stage5_0000114.png in 5.334497928619385 seconds
# Printed stage5_0000115.png in 5.8255579471588135 seconds
# Printed stage5_0000116.png in 4.929322957992554 seconds
# Printed stage5_0000117.png in 5.20986795425415 seconds
# Printed stage5_0000118.png in 4.862086772918701 seconds
# Printed stage5_0000119.png in 5.031949043273926 seconds
# Printed stage5_0000120.png in 5.4154372215271 seconds
# Printed stage5_0000121.png in 5.2859697341918945 seconds
# Printed stage5_0000122.png in 5.490834951400757 seconds
# Printed stage5_0000123.png in 5.303376913070679 seconds
# Printed stage5_0000124.png in 5.796379804611206 seconds
# Printed stage5_0000125.png in 5.168788909912109 seconds
# Printed stage5_0000126.png in 5.5782458782196045 seconds
# Printed stage5_0000127.png in 5.120759963989258 seconds
# Printed stage5_0000128.png in 5.303303003311157 seconds
# Printed stage5_0000129.png in 5.489330768585205 seconds
# Printed stage5_0000130.png in 5.054287910461426 seconds
# Printed stage5_0000131.png in 5.128954172134399 seconds
# Printed stage5_0000132.png in 4.708811044692993 seconds
# Printed stage5_0000133.png in 5.319488763809204 seconds
# Printed stage5_0000134.png in 4.879395961761475 seconds
# Printed stage5_0000135.png in 4.7825798988342285 seconds
# Printed stage5_0000136.png in 5.325446128845215 seconds
# Printed stage5_0000137.png in 4.806486129760742 seconds
# Printed stage5_0000138.png in 4.743503093719482 seconds
# Printed stage5_0000139.png in 5.401906967163086 seconds
# Printed stage5_0000140.png in 4.690874099731445 seconds
# Printed stage5_0000141.png in 5.1610331535339355 seconds
# Printed stage5_0000142.png in 4.850917816162109 seconds
# Printed stage5_0000143.png in 4.553930044174194 seconds
# Printed stage5_0000144.png in 5.161056041717529 seconds
# Printed stage5_0000145.png in 4.899874925613403 seconds
# Printed stage5_0000146.png in 4.813592195510864 seconds
# Printed stage5_0000147.png in 5.20556902885437 seconds
# Printed stage5_0000148.png in 4.982655048370361 seconds
# Printed stage5_0000149.png in 4.77944803237915 seconds
# Printed stage5_0000150.png in 5.19712495803833 seconds
# Printed stage5_0000151.png in 5.093425035476685 seconds
# Printed stage5_0000152.png in 4.83656120300293 seconds
# Printed stage5_0000153.png in 5.320224046707153 seconds
# Printed stage5_0000154.png in 4.983540058135986 seconds
# Printed stage5_0000155.png in 4.77291202545166 seconds
# Printed stage5_0000156.png in 5.664545059204102 seconds
# Printed stage5_0000157.png in 4.91090989112854 seconds
# Printed stage5_0000158.png in 5.466746807098389 seconds
# Printed stage5_0000159.png in 5.35863995552063 seconds
# Printed stage5_0000160.png in 4.994990110397339 seconds
# Printed stage5_0000161.png in 5.370116949081421 seconds
# Printed stage5_0000162.png in 4.8103227615356445 seconds
# Printed stage5_0000163.png in 4.83418607711792 seconds
# Printed stage5_0000164.png in 5.214399099349976 seconds
# Printed stage5_0000165.png in 4.797456979751587 seconds
# Printed stage5_0000166.png in 5.295677900314331 seconds
# Printed stage5_0000167.png in 4.570064067840576 seconds
# Printed stage5_0000168.png in 5.286776065826416 seconds
# Printed stage5_0000169.png in 4.6980299949646 seconds
# Printed stage5_0000170.png in 4.75292181968689 seconds
# Printed stage5_0000171.png in 5.341939926147461 seconds
# Printed stage5_0000172.png in 4.710003852844238 seconds
# Printed stage5_0000173.png in 4.752532958984375 seconds
# Printed stage5_0000174.png in 5.419255971908569 seconds
# Printed stage5_0000175.png in 4.887373208999634 seconds
# Printed stage5_0000176.png in 4.778918981552124 seconds
# Printed stage5_0000177.png in 5.4355058670043945 seconds
# Printed stage5_0000178.png in 4.779004096984863 seconds
# Printed stage5_0000179.png in 4.713576793670654 seconds
# Printed stage5_0000180.png in 5.536118984222412 seconds
# Printed stage5_0000181.png in 5.012891054153442 seconds
# Printed stage5_0000182.png in 4.985365152359009 seconds
# Printed stage5_0000183.png in 4.862526893615723 seconds
# Printed stage5_0000184.png in 5.663931131362915 seconds
# Printed stage5_0000185.png in 4.783174753189087 seconds
# Printed stage5_0000186.png in 4.881846189498901 seconds
# Printed stage5_0000187.png in 5.690437316894531 seconds
# Printed stage5_0000188.png in 4.824906826019287 seconds
# Printed stage5_0000189.png in 4.7676568031311035 seconds
# Printed stage5_0000190.png in 5.391912937164307 seconds
# Printed stage5_0000191.png in 4.458132266998291 seconds
# Printed stage5_0000192.png in 4.8771889209747314 seconds
# Printed stage5_0000193.png in 4.819561004638672 seconds
# Printed stage5_0000194.png in 5.556330919265747 seconds
# Printed stage5_0000195.png in 4.864706754684448 seconds
# Printed stage5_0000196.png in 4.9038872718811035 seconds
# Printed stage5_0000197.png in 4.740314960479736 seconds
# Printed stage5_0000198.png in 5.620091915130615 seconds
# Printed stage5_0000199.png in 4.954883813858032 seconds
# Printed stage5_0000200.png in 4.853708982467651 seconds
# Printed stage5_0000201.png in 5.734676122665405 seconds
# Printed stage5_0000202.png in 4.7340521812438965 seconds
# Printed stage5_0000203.png in 4.723633766174316 seconds
# Printed stage5_0000204.png in 4.974026918411255 seconds
# Printed stage5_0000205.png in 5.723042011260986 seconds
# Printed stage5_0000206.png in 4.8150928020477295 seconds
# Printed stage5_0000207.png in 5.282494068145752 seconds
# Printed stage5_0000208.png in 4.757571697235107 seconds
# Printed stage5_0000209.png in 5.734309911727905 seconds
# Printed stage5_0000210.png in 4.795506954193115 seconds
# Printed stage5_0000211.png in 4.787069797515869 seconds
# Printed stage5_0000212.png in 5.390344142913818 seconds
# Printed stage5_0000213.png in 5.3551928997039795 seconds
# Printed stage5_0000214.png in 4.950066089630127 seconds
# Printed stage5_0000215.png in 4.577154159545898 seconds
# Printed stage5_0000216.png in 5.9547438621521 seconds
# Printed stage5_0000217.png in 4.664927005767822 seconds
# Printed stage5_0000218.png in 4.702546119689941 seconds
# Printed stage5_0000219.png in 6.202275991439819 seconds
# Printed stage5_0000220.png in 6.155026197433472 seconds
# Printed stage5_0000221.png in 4.842551231384277 seconds
# Printed stage5_0000222.png in 4.907561779022217 seconds
# Printed stage5_0000223.png in 5.051407098770142 seconds
# Printed stage5_0000224.png in 5.844429016113281 seconds
# Printed stage5_0000225.png in 4.9437549114227295 seconds
# Printed stage5_0000226.png in 4.83063006401062 seconds
# Printed stage5_0000227.png in 4.805775880813599 seconds
# Printed stage5_0000228.png in 4.80705189704895 seconds
# Printed stage5_0000229.png in 5.290929794311523 seconds
# Printed stage5_0000230.png in 4.616454124450684 seconds
# Printed stage5_0000231.png in 4.446825981140137 seconds
# Printed stage5_0000232.png in 4.372582912445068 seconds
# Printed stage5_0000233.png in 5.2381391525268555 seconds
# Printed stage5_0000234.png in 4.5941550731658936 seconds
# Printed stage5_0000235.png in 4.409610986709595 seconds
# Printed stage5_0000236.png in 4.409199237823486 seconds
# Printed stage5_0000237.png in 5.255147218704224 seconds
# Printed stage5_0000238.png in 4.440941095352173 seconds
# Printed stage5_0000239.png in 4.229518890380859 seconds
# Printed stage5_0000240.png in 4.466315031051636 seconds
# Printed stage5_0000241.png in 5.167913198471069 seconds
# Printed stage5_0000242.png in 4.460803985595703 seconds
# Printed stage5_0000243.png in 4.487373113632202 seconds
# Printed stage5_0000244.png in 4.492089033126831 seconds
# Printed stage5_0000245.png in 4.52543306350708 seconds
# Printed stage5_0000246.png in 5.138032913208008 seconds
# Printed stage5_0000247.png in 4.426931142807007 seconds
# Printed stage5_0000248.png in 4.5345330238342285 seconds
# Printed stage5_0000249.png in 4.379024028778076 seconds
# Printed stage5_0000250.png in 5.134458065032959 seconds
# Printed stage5_0000251.png in 4.490099906921387 seconds
# Printed stage5_0000252.png in 4.385679006576538 seconds
# Printed stage5_0000253.png in 4.38796591758728 seconds
# Printed stage5_0000254.png in 4.449700117111206 seconds
# Printed stage5_0000255.png in 5.090797185897827 seconds
# Printed stage5_0000256.png in 4.383580207824707 seconds
# Printed stage5_0000257.png in 4.402889013290405 seconds
# Printed stage5_0000258.png in 4.327415704727173 seconds
# Printed stage5_0000259.png in 4.467927932739258 seconds
# Printed stage5_0000260.png in 5.263149976730347 seconds
# Printed stage5_0000261.png in 4.389828681945801 seconds
# Printed stage5_0000262.png in 4.431895017623901 seconds
# Printed stage5_0000263.png in 4.212251901626587 seconds
# Printed stage5_0000264.png in 5.146646022796631 seconds
# Printed stage5_0000265.png in 4.2462990283966064 seconds
# Printed stage5_0000266.png in 4.545553207397461 seconds
# Printed stage5_0000267.png in 4.467171907424927 seconds
# Printed stage5_0000268.png in 4.3817150592803955 seconds
# Printed stage5_0000269.png in 5.178200006484985 seconds
# Printed stage5_0000270.png in 4.316840887069702 seconds
# Printed stage5_0000271.png in 4.327928066253662 seconds
# Printed stage5_0000272.png in 4.477041959762573 seconds
# Printed stage5_0000273.png in 4.268891096115112 seconds
# Printed stage5_0000274.png in 5.07157301902771 seconds
# Printed stage5_0000275.png in 4.5414159297943115 seconds
# Printed stage5_0000276.png in 4.357898950576782 seconds
# Printed stage5_0000277.png in 4.482511043548584 seconds
# Printed stage5_0000278.png in 4.547905921936035 seconds
# Printed stage5_0000279.png in 5.1856770515441895 seconds
# Printed stage5_0000280.png in 4.33015513420105 seconds
# Printed stage5_0000281.png in 4.696743965148926 seconds
# Printed stage5_0000282.png in 4.4000091552734375 seconds
# Printed stage5_0000283.png in 4.348096132278442 seconds
# Printed stage5_0000284.png in 5.362134695053101 seconds
# Printed stage5_0000285.png in 4.343518018722534 seconds
# Printed stage5_0000286.png in 4.390798807144165 seconds
# Printed stage5_0000287.png in 4.207763910293579 seconds
# Printed stage5_0000288.png in 4.383575201034546 seconds
# Printed stage5_0000289.png in 5.160657167434692 seconds
# Printed stage5_0000290.png in 4.431331157684326 seconds
# Printed stage5_0000291.png in 4.447685956954956 seconds
# Printed stage5_0000292.png in 4.356494188308716 seconds
# Printed stage5_0000293.png in 4.373303651809692 seconds
# Printed stage5_0000294.png in 4.327590227127075 seconds
# Printed stage5_0000295.png in 5.260272026062012 seconds
# Printed stage5_0000296.png in 4.420464038848877 seconds
# Printed stage5_0000297.png in 4.417931079864502 seconds
# Printed stage5_0000298.png in 4.372279167175293 seconds
# Printed stage5_0000299.png in 4.40258002281189 seconds
